# %%
#!pip install -U scikit-learn
#!pip install autograd

# %%
# !python3 --version
# Out:
# Python 3.9.1

# %% [markdown]
# # 1st Assignment: NN's from Scratch
#
# By: Jan Leyva Massagué
#
# The objective is to build from scratch a neural network to perform  classification. Let's first consider the follwing 2-class dataset:

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as pltcolors
import plotly.graph_objects as go
from sklearn import metrics
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib
import autograd.numpy as np
from autograd import grad
from autograd.misc import flatten
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns



n = 1000

# Display plots inline and change default figure size
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (8.0, 6.0)

# Generate a dataset and plot it
np.random.seed(0)
X, y = sklearn.datasets.make_moons(n, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, alpha=0.45)

# %%
# Function to plot Confusion Matrix
def plotHeatMap(X, classes, title=None, fmt='.2g', ax=None, xlabel=None, ylabel=None):
    """ Fix heatmap plot from Seaborn with pyplot 3.1.0, 3.1.1
        https://stackoverflow.com/questions/56942670/matplotlib-seaborn-first-and-last-row-cut-in-half-of-heatmap-plot
    """
    ax = sns.heatmap(X, xticklabels=classes, yticklabels=classes, annot=True, \
                     fmt=fmt, cmap=plt.cm.Blues, ax=ax) #notation: "annot" not "annote"
    bottom, top = ax.get_ylim()
    ax.set_ylim(bottom + 0.5, top - 0.5)
    if title:
        ax.set_title(title)
    if xlabel:
        ax.set_xlabel(xlabel)
    if ylabel:
        ax.set_ylabel(ylabel)
        
def plotConfusionMatrix(yTrue, yEst, classes, title=None, fmt='.2g', ax=None):
    plotHeatMap(confusion_matrix(yTrue, yEst), classes, title, fmt, ax, xlabel='Estimations', \
                ylabel='True values');
    print("Accuracy:", round(accuracy_score(yTrue, yEst)*100, 2), "%")

# %% [markdown]
# We will use a **3-layer classification neural network** with one input layer, one hidden layer, and one output layer.
#
# The number of nodes in the input layer will be determined by the dimensionality of our data (2). Similarly, the number of nodes in the output layer is determined by the number of classes $C$ we have (also 2).
#
# Our network makes predictions using forward propagation, which is just a bunch of matrix multiplications and the application of the activation function $\sigma$.
#
# If $x$ is the input to our network then we calculate our prediction $\hat{y}$ as follows:
#
# $$ z_1 = x W_1 + b_1 $$
# $$ a_1 = \sigma(z_1) $$
# $$ z_2 = a_1 W_2 + b_2$$
# $$ y = \mbox{softmax}({z_2})$$
#
# where $y$ is a multidimensional vector representing a probability distribution over classes, $\sigma$ is a non linear function and $W_1, b_1, W_2, b_2$ are parameters of our network, which we need to learn from our training data. You can think of the parameters $W$ as matrices transforming data between layers of the network.
#
# Looking at the matrix multiplications above we can figure out the dimensionality of these matrices in our problem. If we use 500 nodes for our hidden layer then $W_1 \in \mathbb{R}^{2\times500}$, $b_1 \in \mathbb{R}^{500}$, $W_2 \in \mathbb{R}^{500\times2}$, $b_2 \in \mathbb{R}^{2}$.
#
# The last layer is a `softmax` function. The softmax function is a generalization of the logistic function to multiple dimensions. It is used to normalize the output of a network to a probability distribution over predicted output classes.
#
# The softmax function takes as input a vector $C$ of real numbers, and normalizes it into a probability distribution consisting of $C$ probabilities proportional to the exponentials of the input numbers:
#
# $$softmax(z_i) = \frac{exp(z_i)}{\sum_{j=1}^{C}exp(z_j))}$$
#
# A common choice with the softmax output is the **cross-entropy loss**. If we have $N$ training examples in our minibatch dataset and $C$ classes, then the loss for our prediction $\hat{y}$ for that minibatch with respect to the true labels $y$ is given by:
#
# $$
# \begin{aligned}
# L(y,\hat{y}) = - \frac{1}{N} \sum_{n \in N} \sum_{i \in C} y_{n,i} \log\hat{y}_{n,i}
# \end{aligned}
# $$

# %%
num_examples = len(X) # training set size
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
sigma = np.tanh # activation function

# Gradient descent parameters 
epsilon = 0.03 # learning rate for gradient descent
reg_lambda = 0.01 # regularization strength

# %%
np.tanh(1)
# Out:
# 0.7615941559557649

# %% [markdown]
# ### Model 1: 1 hidden layer + tanh

# %%
# loss function for a 3-layer MLP
def loss(model):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    # Forward propagation to calculate our predictions
    z1 = np.dot(X,W1) + b1
    a1 = sigma(z1)
    z2 = np.dot(a1,W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    # Calculating the loss
    corect_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(corect_logprobs)
    # Add regulatization term to loss (optional)
    data_loss += reg_lambda * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
    return 1./num_examples * data_loss

# forward propagation
def predict(model, x):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    z1 = np.dot(x,W1) + b1
    a1 = sigma(z1)
    z2 = np.dot(a1,W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return np.argmax(probs, axis=1)

# %%
# This function learns parameters for the neural network and returns the model.
# - nn_hdim: Number of nodes in the hidden layer
# - num_passes: Number of passes through the training data for gradient descent
# - print_loss: If True, print the loss every 1000 iterations

def build_model(nn_hdim, actFunction = "tanh", num_passes=5000, print_loss=False):
    
    if actFunction == "tanh":
        sigma = np.tanh
    elif actFunction == "ReLU":
        sigma = reLU

    # Initialize the parameters to random values. 
    np.random.seed(0)
    W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, nn_hdim))
    W2 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    b2 = np.zeros((1, nn_output_dim))

    # This is what we return at the end
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
    
    # Gradient descent. For each batch...
    for i in range(0, num_passes):

        # Forward propagation
        predict(model, X)

        # computing the derivative by AD        
        gradient_loss = grad(loss)

        # flattening nested containers containing numpy arrays
        # Returns 1D numpy array and an unflatten function.
        model_flat, unflatten_m = flatten(model)
        grad_flat, unflatten_g = flatten(gradient_loss(model))
        
        # gradient descend
        model_flat -= grad_flat * epsilon
        model = unflatten_m(model_flat)

        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % 1000 == 0:
            print("Loss after iteration %i: %f" %(i, loss(model)))
        if i == (num_passes-1):
            print("End of the trainning process") 
    return model

# %%
# Build a model with a 3-dimensional hidden layer
model_tanh_1hd = build_model(3, actFunction = "asdas", print_loss=True)
# Out:
# Loss after iteration 0: 0.576967
# Loss after iteration 1000: 0.292965
# Loss after iteration 2000: 0.282116
# Loss after iteration 3000: 0.263447
# Loss after iteration 4000: 0.235814
# End of the trainning process

# %%
def plot_decision_boundary(pred_func):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, alpha=0.45)
    plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.45)

    
# Plot the decision boundary
plot_decision_boundary(lambda x: predict(modelV1, x))
plt.title("Decision Boundary for hidden layer size 3")
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 3')

# %%
pred = predict(modelV1, X)
plotConfusionMatrix(y, pred, classes = 2)
# Out:
# Accuracy: 96.8 %

# %% [markdown]
# # Exercise 1
#
# Add an additional layer to your neural network model. Change the activation function and use a ReLU. Does it work?
#
#
# ## First we will try with an additional layer
#
# ### Model 2: 2 hidden layer + tanh

# %%
# loss function for a 4-layer MLP
def loss(model):
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
    # Forward propagation to calculate our predictions
    z1 = np.dot(X,W1) + b1
    a1 = sigma(z1)              # changed the activation function to `ReLU`
    z2 = np.dot(a1,W2) + b2
    a2 = sigma(z2)              # changed the activation function to `ReLU`
    z3 = np.dot(a2,W3) + b3
    exp_scores = np.exp(z3)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    # Calculating the loss
    corect_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(corect_logprobs)
    # Add regulatization term to loss (optional)
    data_loss += reg_lambda * (np.sum(np.square(W1)) + np.sum(np.square(W2))) + np.sum(np.square(W3))
    return 1./num_examples * data_loss

# forward propagation
def predict(model, x):
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
    z1 = np.dot(x,W1) + b1
    a1 = sigma(z1)              # changed the activation function to `ReLU`
    z2 = np.dot(a1,W2) + b2
    a2 = sigma(z2)              # changed the activation function to `ReLU`
    z3 = np.dot(a2,W3) + b3
    exp_scores = np.exp(z3)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return np.argmax(probs, axis=1)

# %%
# This function learns parameters for the neural network and returns the model.
# - nn_hdim: Number of nodes in the hidden layer
# - num_passes: Number of passes through the training data for gradient descent
# - print_loss: If True, print the loss every 1000 iterations

def build_model(nn_hdim, num_passes=50000, print_loss=False):
    
    # Initialize the parameters to random values. 
    np.random.seed(0)
    W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, nn_hdim))
    W2 = np.random.randn(nn_hdim, nn_hdim) / np.sqrt(nn_hdim)
    b2 = np.zeros((1, nn_hdim))
    W3 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    b3 = np.zeros((1, nn_output_dim))

    # This is what we return at the end
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3': W3, 'b3': b3}
    
    # Gradient descent. For each batch...
    for i in range(0, num_passes):

        # Forward propagation
        predict(model, X)

        # computing the derivative by AD        
        gradient_loss = grad(loss)

        # flattening nested containers containing numpy arrays
        # Returns 1D numpy array and an unflatten function.
        model_flat, unflatten_m = flatten(model)
        grad_flat, unflatten_g = flatten(gradient_loss(model))
        
        # gradient descend
        model_flat -= grad_flat * epsilon
        model = unflatten_m(model_flat)

        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % 1000 == 0:
            print("Loss after iteration %i: %f" %(i, loss(model)))
    
    return model

# %%
# Build a model with a 3-dimensional hidden layer
model_4layers = build_model(3, print_loss=False)

# %%
# Plot the decision boundary
plot_decision_boundary(lambda x: predict(model_4layers, x))
plt.title("Decision Boundary for hidden layer size 3")
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 3')

# %%
pred_4layers = predict(model_4layers, X)
plotConfusionMatrix(y, pred_4layers, classes = 2)
# Out:
# Accuracy: 96.9 %

# %% [markdown]
# ##  Now we going to check what happen if we change the activation function to ReLU
#
# Parametric ReLUs (PReLUs) take this idea further by making the coefficient of leakage into a parameter that is learned along with the other neural-network parameters.
#
# \begin{cases}x&{\text{if }}x>0,\\ax&{\text{otherwise}}.\end{cases}
#
#
# otherwise:
#
#
# Note that for a ≤ 1, this is equivalent to
#
# $$f(x)=\max(x,ax)$$
#
# And we going to applt:
#
# $$f(x)=\max(0, x)$$
#
# We definde as:

# %%
def reLU(x):
    x = np.maximum(0, x)
    return x

# %% [markdown]
# ### Model 3: 2 hidden layer + ReLU

# %%
# loss function for a 3-layer MLP
def loss(model):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    # Forward propagation to calculate our predictions
    z1 = np.dot(X,W1) + b1
    a1 = reLU(z1)
    z2 = np.dot(a1,W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    # Calculating the loss
    corect_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(corect_logprobs)
    # Add regulatization term to loss (optional)
    data_loss += reg_lambda * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
    return 1./num_examples * data_loss

# forward propagation
def predict(model, x):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    z1 = np.dot(x,W1) + b1
    a1 = reLU(z1)
    z2 = np.dot(a1,W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return np.argmax(probs, axis=1)

# %%
# This function learns parameters for the neural network and returns the model.
# - nn_hdim: Number of nodes in the hidden layer
# - num_passes: Number of passes through the training data for gradient descent
# - print_loss: If True, print the loss every 1000 iterations

def build_model(nn_hdim, num_passes=50000, print_loss=False):
    
    # Initialize the parameters to random values. 
    np.random.seed(0)
    W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, nn_hdim))
    W2 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    b2 = np.zeros((1, nn_output_dim))

    # This is what we return at the end
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
    
    # Gradient descent. For each batch...
    for i in range(0, num_passes):

        # Forward propagation
        predict(model, X)

        # computing the derivative by AD        
        gradient_loss = grad(loss)

        # flattening nested containers containing numpy arrays
        # Returns 1D numpy array and an unflatten function.
        model_flat, unflatten_m = flatten(model)
        grad_flat, unflatten_g = flatten(gradient_loss(model))
        
        # gradient descend
        model_flat -= grad_flat * epsilon
        model = unflatten_m(model_flat)

        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % 1000 == 0:
            print("Loss after iteration %i: %f" %(i, loss(model)))
        if i == (num_passes-1):
            print("End of the trainning process") 
    return model

# %%
# Build a model with a 3-dimensional hidden layer
model_ReLU1 = build_model(3, print_loss=False)
# Out:
# End of the trainning process

# %%
# Plot the decision boundary
plot_decision_boundary(lambda x: predict(model_ReLU1, x))
plt.title("Decision Boundary for hidden layer size 3")
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 3')

# %%
pred_ReLU1 = predict(model_ReLU1, X)
plotConfusionMatrix(y, pred_ReLU1, classes = 2)
# Out:
# Accuracy: 88.7 %

# %% [markdown]
# ### Model 4: 2 hidden layer + ReLU

# %%
# loss function for a 3-layer MLP
def loss(model):
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
    # Forward propagation to calculate our predictions
    z1 = np.dot(X,W1) + b1
    a1 = reLU(z1)              # changed the activation function to `ReLU`
    z2 = np.dot(a1,W2) + b2
    a2 = reLU(z2)              # changed the activation function to `ReLU`
    z3 = np.dot(a2,W3) + b3
    exp_scores = np.exp(z3)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    # Calculating the loss
    corect_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(corect_logprobs)
    # Add regulatization term to loss (optional)
    data_loss += reg_lambda * (np.sum(np.square(W1)) + np.sum(np.square(W2))) + np.sum(np.square(W3))
    return 1./num_examples * data_loss

# forward propagation
def predict(model, x):
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
    z1 = np.dot(x,W1) + b1
    a1 = reLU(z1)              # changed the activation function to `ReLU`
    z2 = np.dot(a1,W2) + b2
    a2 = reLU(z2)              # changed the activation function to `ReLU`
    z3 = np.dot(a2,W3) + b3
    exp_scores = np.exp(z3)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return np.argmax(probs, axis=1)

# %%
# This function learns parameters for the neural network and returns the model.
# - nn_hdim: Number of nodes in the hidden layer
# - num_passes: Number of passes through the training data for gradient descent
# - print_loss: If True, print the loss every 1000 iterations

def build_model(nn_hdim, num_passes=50000, print_loss=False):
    
    # Initialize the parameters to random values. 
    np.random.seed(0)
    W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, nn_hdim))
    W2 = np.random.randn(nn_hdim, nn_hdim) / np.sqrt(nn_hdim)
    b2 = np.zeros((1, nn_hdim))
    W3 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    b3 = np.zeros((1, nn_output_dim))
 
    
    # This is what we return at the end
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3': W3, 'b3': b3}
    
    # Gradient descent. For each batch...
    for i in range(0, num_passes):

        # Forward propagation
        predict(model, X)

        # computing the derivative by AD        
        gradient_loss = grad(loss)

        # flattening nested containers containing numpy arrays
        # Returns 1D numpy array and an unflatten function.
        model_flat, unflatten_m = flatten(model)
        grad_flat, unflatten_g = flatten(gradient_loss(model))
        
        # gradient descend
        model_flat -= grad_flat * epsilon
        model = unflatten_m(model_flat)

        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % 1000 == 0:
            print("Loss after iteration %i: %f" %(i, loss(model)))
    
        if i == (num_passes-1):
            print("End of the trainning process") 
            
    return model

# %%
# Build a model with a 3-dimensional hidden layer
model_ReLU = build_model(3, print_loss=False)
# Out:
# End of the trainning process

# %%
# Plot the decision boundary
plot_decision_boundary(lambda x: predict(model_ReLU, x))
plt.title("Decision Boundary for hidden layer size 3")
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 3')

# %%
pred_ReLU = predict(model_ReLU, X)
plotConfusionMatrix(y, pred_ReLU, classes = 2)
# Out:
# Accuracy: 88.7 %

# %% [markdown]
# ### Summary Table
#
# In this section are summary the metrics and architecture of the three different **NN**:

# %%
# Calc the accuracy for each architecture
acc_1tanh = accuracy_score(y, pred)
acc_2tanh = accuracy_score(y, pred_4layers)
acc_1reLU = accuracy_score(y, pred_ReLU1)
acc_2reLU = accuracy_score(y, pred_ReLU)


fig = go.Figure(data=[go.Table(header=dict(values=['Model', 'nº hidden layers', 'Activation function','Accuracy']),
                 cells=dict(values=[["Model 1", "Model 2", "Model 3", "Model 4"], [1, 2 , 1, 2], ['tanh', 'tanh', 'ReLU', 'ReLU'],
                                    [acc_1tanh, acc_2tanh, acc_1reLU, acc_2reLU]]))
                     ])

fig.show()
# Out:
# <div>                            <div id="08467845-df61-4be4-a4da-d6874916d4fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08467845-df61-4be4-a4da-d6874916d4fd")) {                    Plotly.newPlot(                        "08467845-df61-4be4-a4da-d6874916d4fd",                        [{"cells":{"values":[["Model 1","Model 2","Model 3","Model 4"],[1,2,1,2],["tanh","tanh","ReLU","ReLU"],[0.968,0.969,0.887,0.887]]},"header":{"values":["Model","n\u00ba hidden layers","Activation function","Accuracy"]},"type":"table"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marke ...
#
# var gd = document.getElementById('08467845-df61-4be4-a4da-d6874916d4fd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).displ

# %% [markdown]
# # Exercise 2
#
# Design (change parameters) and train a NN to classify the following dataset.

# %%
import numpy
import matplotlib.pyplot as plt

def twospirals(n_points, noise=.5):
    """
     Returns the two spirals dataset.
    """
    n = numpy.sqrt(numpy.random.rand(n_points,1)) * 780 * (2*np.pi)/360
    d1x = -numpy.cos(n)*n + numpy.random.rand(n_points,1) * noise
    d1y = numpy.sin(n)*n + numpy.random.rand(n_points,1) * noise
    return (numpy.vstack((numpy.hstack((d1x,d1y)),numpy.hstack((-d1x,-d1y)))), 
            numpy.hstack((numpy.zeros(n_points),numpy.ones(n_points))))

X, y = twospirals(500)

y = y.astype(int)


plt.title('training set')
plt.plot(X[y==0,0], X[y==0,1], '.', label='class 1')
plt.plot(X[y==1,0], X[y==1,1], '.', label='class 2')
plt.legend()
plt.show()

# %% [markdown]
# ## Approach for spiral data set
#
# This dataset is hard to classify due to the non linearity of the two groups. The approach by **NN** will have `ReLU` activation function and two hidden layer of 8 neurns each one. As well, we doing to change the `epsilon` = 0.03 and
# `reg_lambda` = 0.01. Also the number of iterations are reach to 100000.

# %%
num_examples = len(X) # training set size
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
sigma = np.tanh # activation function

# Gradient descent parameters 
epsilon = 0.03 # learning rate for gradient descent
reg_lambda = 0.01 # regularization strength

# %%
# loss function for a 3-layer MLP
def loss(model):
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
    # Forward propagation to calculate our predictions
    z1 = np.dot(X,W1) + b1
    a1 = reLU(z1)              # changed the activation function to `ReLU`
    z2 = np.dot(a1,W2) + b2
    a2 = reLU(z2)              # changed the activation function to `ReLU`
    z3 = np.dot(a2,W3) + b3
    exp_scores = np.exp(z3)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    # Calculating the loss
    corect_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(corect_logprobs)
    # Add regulatization term to loss (optional)
    data_loss += reg_lambda * (np.sum(np.square(W1)) + np.sum(np.square(W2))) + np.sum(np.square(W3))
    return 1./num_examples * data_loss

# forward propagation
def predict(model, x):
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
    z1 = np.dot(x,W1) + b1
    a1 = reLU(z1)              # changed the activation function to `ReLU`
    z2 = np.dot(a1,W2) + b2
    a2 = reLU(z2)              # we try to change the second act f(x) as linear
    z3 = np.dot(a2,W3) + b3
    exp_scores = np.exp(z3)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return np.argmax(probs, axis=1)

# %%
# This function learns parameters for the neural network and returns the model.
# - nn_hdim: Number of nodes in the hidden layer
# - num_passes: Number of passes through the training data for gradient descent
# - print_loss: If True, print the loss every 1000 iterations

def build_model(nn_hdim, num_passes=300000, print_loss=False):
    
    # Initialize the parameters to random values. 
    np.random.seed(0)
    W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, nn_hdim))
    W2 = np.random.randn(nn_hdim, nn_hdim) / np.sqrt(nn_hdim)
    b2 = np.zeros((1, nn_hdim))
    W3 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    b3 = np.zeros((1, nn_output_dim))

    # This is what we return at the end
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3': W3, 'b3': b3}
    
    # Gradient descent. For each batch...
    for i in range(0, num_passes):

        # Forward propagation
        predict(model, X)

        # computing the derivative by AD        
        gradient_loss = grad(loss)

        # flattening nested containers containing numpy arrays
        # Returns 1D numpy array and an unflatten function.
        model_flat, unflatten_m = flatten(model)
        grad_flat, unflatten_g = flatten(gradient_loss(model))
        
        # gradient descend
        model_flat -= grad_flat * epsilon
        model = unflatten_m(model_flat)

        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % 1000 == 0:
            print("Loss after iteration %i: %f" %(i, loss(model)))
    
        if i == (num_passes-1):
            print("End of the trainning process") 
            
    return model

# %%
# Build a model with a 3-dimensional hidden layer
model_Spiral = build_model(8, print_loss=False)
# Out:
# End of the trainning process

# %%
# Build a model with a 3-dimensional hidden layer
model_Spiralv2 = build_model(8, print_loss=True)
# Out:
# Loss after iteration 0: 1.071582
# Loss after iteration 1000: 0.654303
# Loss after iteration 2000: 0.646317
# Loss after iteration 3000: 0.641153
# Loss after iteration 4000: 0.638546
# Loss after iteration 5000: 0.635626
# Loss after iteration 6000: 0.633414
# Loss after iteration 7000: 0.631397
# Loss after iteration 8000: 0.629966
# Loss after iteration 9000: 0.629080
# Loss after iteration 10000: 0.628537
# Loss after iteration 11000: 0.628102
# Loss after iteration 12000: 0.627522
# Loss after iteration 13000: 0.626966
# Loss after iteration 14000: 0.626580
# Loss after iteration 15000: 0.626075
# Loss after iteration 16000: 0.625730
# Loss after iteration 17000: 0.625308
# Loss after iteration 18000: 0.625908
# Loss after iteration 19000: 0.624861
# Loss after iteration 20000: 0.624694
# Loss after iteration 21000: 0.624651
# Loss after iteration 22000: 0.624355
# Loss after iteration 23000: 0.624147
# Loss after iteration 24000: 0.623917
# Loss after iteration 25000: 0.623764
# Loss after iteration 26000: 0.623710
# Loss after iteration 27000: 0.623426
# Loss after iteration 28000: 0.623349
# Loss after iteration 29000: 0.623232
# Loss after iteration 30000: 0.623856
# Loss after iteration 31000: 0.623032
# Loss after iteration 32000: 0.622952
# Loss after iteration 33000: 0.622977
# Loss after iteration 34000: 0.622789
# Loss after iteration 35000: 0.622694
# Loss after iteration 36000: 0.622855
# Loss after iteration 37000: 0.622873
# Loss after iteration 38000: 0.622801
# Loss after iteration 39000: 0.622680
# Loss after iteration 40000: 0.622547
# Loss after iteration 41000: 0.622548
# Loss after iteration 42000: 0.622172
# Loss after iteration 43000: 0.622085
# Loss after iteration 44000: 0.622481
# Loss after iteration 45000: 0.622197
# Loss after iteration 46000: 0.622127
# Loss after iteration 47000: 0.622037
# Loss after iteration 48000: 0.621741
# Loss after iteration 49000: 0.622261
# Loss after iteration 50000: 0.621571
# Loss after iteration 51000: 0.621450
# Loss after iteration 52000: 0.622042
# Loss after iteration 53000: 0.621838
# Loss after iteration 54000: 0.621247
# Loss after iteration 55000: 0.621834
# Loss after iteration 56000: 0.621190
# Loss after iteration 57000: 0.621370
# Loss after iteration 58000: 0.621010
# Loss after iteration 59000: 0.621577
# Loss after iteration 60000: 0.620957
# Loss after iteration 61000: 0.621677
# Loss after iteration 62000: 0.621635
# Loss after iteration 63000: 0.621543
# Loss after iteration 64000: 0.621309
# Loss after iteration 65000: 0.621301
# Loss after iteration 66000: 0.621272
# Loss after iteration 67000: 0.621307
# Loss after iteration 68000: 0.621145
# Loss after iteration 69000: 0.621160
# Loss after iteration 70000: 0.621152
# Loss after iteration 71000: 0.621054
# Loss after iteration 72000: 0.621030
# Loss after iteration 73000: 0.620944
# Loss after iteration 74000: 0.621014
# Loss after iteration 75000: 0.620969
# Loss after iteration 76000: 0.620988
# Loss after iteration 77000: 0.620971
# Loss after iteration 78000: 0.621075
# Loss after iteration 79000: 0.620471
# Loss after iteration 80000: 0.620982
# Loss after iteration 81000: 0.620943
# Loss after iteration 82000: 0.620627
# Loss after iteration 83000: 0.620918
# Loss after iteration 84000: 0.620946
# Loss after iteration 85000: 0.620919
# Loss after iteration 86000: 0.620825
# Loss after iteration 87000: 0.620907
# Loss after iteration 88000: 0.620907
# Loss after iteration 89000: 0.620910
# Loss after iteration 90000: 0.620830
# Loss after iteration 91000: 0.620859
# Loss after iteration 92000: 0.620706
# Loss after iteration 93000: 0.620882
# Loss after iteration 94000: 0.620681
# Loss after iteration 95000: 0.620567
# Loss after iteration 96000: 0.620575
# Loss after iteration 97000: 0.620566
# Loss after iteration 98000: 0.620398
# Loss after iteration 99000: 0.620390
# Loss after iteration 100000: 0.620382
# Loss after iteration 101000: 0.620343
# Loss after iteration 102000: 0.620347
# Loss after iteration 103000: 0.620018
# Loss after iteration 104000: 0.620193
# Loss after iteration 105000: 0.619933
# Loss after iteration 106000: 0.619795
# Loss after iteration 107000: 0.619698
# Loss after iteration 108000: 0.619687
# Loss after iteration 109000: 0.619579
# Loss after iteration 110000: 0.619487
# Loss after iteration 111000: 0.619439
# Loss after iteration 112000: 0.619388
# Loss after iteration 113000: 0.619289
# Loss after iteration 114000: 0.619156
# Loss after iteration 115000: 0.619002
# Loss after iteration 116000: 0.618948
# Loss after iteration 117000: 0.618794
# Loss after iteration 118000: 0.618717
# Loss after iteration 119000: 0.618520
# Loss after iteration 120000: 0.618378
# Loss after iteration 121000: 0.618277
# Loss after iteration 122000: 0.618047
# Loss after iteration 123000: 0.617867
# Loss after iteration 124000: 0.617672
# Loss after iteration 125000: 0.617454
# Loss after iteration 126000: 0.617238
# Loss after iteration 127000: 0.616872
# Loss after iteration 128000: 0.616583
# Loss after iteration 129000: 0.613750
# Loss after iteration 130000: 0.612152
# Loss after iteration 131000: 0.610780
# Loss after iteration 132000: 0.608651
# Loss after iteration 133000: 0.606221
# Loss after iteration 134000: 0.603832
# Loss after iteration 135000: 0.601632
# Loss after iteration 136000: 0.599656
# Loss after iteration 137000: 0.597704
# Loss after iteration 138000: 0.596993
# Loss after iteration 139000: 0.594066
# Loss after iteration 140000: 0.592529
# Loss after iteration 141000: 0.591794
# Loss after iteration 142000: 0.589861
# Loss after iteration 143000: 0.588534
# Loss after iteration 144000: 0.587667
# Loss after iteration 145000: 0.584170
# Loss after iteration 146000: 0.582592
# Loss after iteration 147000: 0.582536
# Loss after iteration 148000: 0.581459
# Loss after iteration 149000: 0.578753
# Loss after iteration 150000: 0.578459
# Loss after iteration 151000: 0.576881
# Loss after iteration 152000: 0.576713
# Loss after iteration 153000: 0.576425
# Loss after iteration 154000: 0.575828
# Loss after iteration 155000: 0.574541
# Loss after iteration 156000: 0.573834
# Loss after iteration 157000: 0.573382
# Loss after iteration 158000: 0.573570
# Loss after iteration 159000: 0.573009
# Loss after iteration 160000: 0.572168
# Loss after iteration 161000: 0.571878
# Loss after iteration 162000: 0.572216
# Loss after iteration 163000: 0.571570
# Loss after iteration 164000: 0.571162
# Loss after iteration 165000: 0.570952
# Loss after iteration 166000: 0.570760
# Loss after iteration 167000: 0.570521
# Loss after iteration 168000: 0.570514
# Loss after iteration 169000: 0.570161
# Loss after iteration 170000: 0.569846
# Loss after iteration 171000: 0.569576
# Loss after iteration 172000: 0.569838
# Loss after iteration 173000: 0.569880
# Loss after iteration 174000: 0.569452
# Loss after iteration 175000: 0.566875
# Loss after iteration 176000: 0.557706
# Loss after iteration 177000: 0.549344
# Loss after iteration 178000: 0.544881
# Loss after iteration 179000: 0.529172
# Loss after iteration 180000: 0.507513
# Loss after iteration 181000: 0.483653
# Loss after iteration 182000: 0.474979
# Loss after iteration 183000: 0.423523
# Loss after iteration 184000: 0.416731
# Loss after iteration 185000: 0.406879
# Loss after iteration 186000: 0.401377
# Loss after iteration 187000: 0.396749
# Loss after iteration 188000: 0.393085
# Loss after iteration 189000: 0.389372
# Loss after iteration 190000: 0.387157
# Loss after iteration 191000: 0.383911
# Loss after iteration 192000: 0.382161
# Loss after iteration 193000: 0.380601
# Loss after iteration 194000: 0.379829
# Loss after iteration 195000: 0.371013
# Loss after iteration 196000: 0.368059
# Loss after iteration 197000: 0.365780
# Loss after iteration 198000: 0.363613
# Loss after iteration 199000: 0.362241
# Loss after iteration 200000: 0.361050
# Loss after iteration 201000: 0.360081
# Loss after iteration 202000: 0.358365
# Loss after iteration 203000: 0.357519
# Loss after iteration 204000: 0.356734
# Loss after iteration 205000: 0.356086
# Loss after iteration 206000: 0.355252
# Loss after iteration 207000: 0.354319
# Loss after iteration 208000: 0.353320
# Loss after iteration 209000: 0.351597
# Loss after iteration 210000: 0.351179
# Loss after iteration 211000: 0.350613
# Loss after iteration 212000: 0.350018
# Loss after iteration 213000: 0.349241
# Loss after iteration 214000: 0.348894
# Loss after iteration 215000: 0.307175
# Loss after iteration 216000: 0.284130
# Loss after iteration 217000: 0.247079
# Loss after iteration 218000: 0.245465
# Loss after iteration 219000: 0.232591
# Loss after iteration 220000: 0.201672
# Loss after iteration 221000: 0.188227
# Loss after iteration 222000: 0.171528
# Loss after iteration 223000: 0.157691
# Loss after iteration 224000: 0.150504
# Loss after iteration 225000: 0.143449
# Loss after iteration 226000: 0.139926
# Loss after iteration 227000: 0.135467
# Loss after iteration 228000: 0.131115
# Loss after iteration 229000: 0.124077
# Loss after iteration 230000: 0.117387
# Loss after iteration 231000: 0.113567
# Loss after iteration 232000: 0.125438
# Loss after iteration 233000: 0.095131
# Loss after iteration 234000: 0.089714
# Loss after iteration 235000: 0.086418
# Loss after iteration 236000: 0.083782
# Loss after iteration 237000: 0.081936
# Loss after iteration 238000: 0.080401
# Loss after iteration 239000: 0.079053
# Loss after iteration 240000: 0.077919
# Loss after iteration 241000: 0.076976
# Loss after iteration 242000: 0.076134
# Loss after iteration 243000: 0.075397
# Loss after iteration 244000: 0.074656
# Loss after iteration 245000: 0.066669
# Loss after iteration 246000: 0.063492
# Loss after iteration 247000: 0.061837
# Loss after iteration 248000: 0.059702
# Loss after iteration 249000: 0.061898
# Loss after iteration 250000: 0.056604
# Loss after iteration 251000: 0.054083
# Loss after iteration 252000: 0.053581
# Loss after iteration 253000: 0.052676
# Loss after iteration 254000: 0.053673
# Loss after iteration 255000: 0.056959
# Loss after iteration 256000: 0.051389
# Loss after iteration 257000: 0.054094
# Loss after iteration 258000: 0.082345
# Loss after iteration 259000: 0.051082
# Loss after iteration 260000: 0.056699
# Loss after iteration 261000: 0.050500
# Loss after iteration 262000: 0.054758
# Loss after iteration 263000: 0.049167
# Loss after iteration 264000: 0.049789
# Loss after iteration 265000: 0.053089
# Loss after iteration 266000: 0.047956
# Loss after iteration 267000: 0.047603
# Loss after iteration 268000: 0.050908
# Loss after iteration 269000: 0.050067
# Loss after iteration 270000: 0.047847
# Loss after iteration 271000: 0.047360
# Loss after iteration 272000: 0.053396
# Loss after iteration 273000: 0.048174
# Loss after iteration 274000: 0.048018
# Loss after iteration 275000: 0.059947
# Loss after iteration 276000: 0.049339
# Loss after iteration 277000: 0.046796
# Loss after iteration 278000: 0.046175
# Loss after iteration 279000: 0.049865
# Loss after iteration 280000: 0.077486
# Loss after iteration 281000: 0.052396
# Loss after iteration 282000: 0.046344
# Loss after iteration 283000: 0.045452
# Loss after iteration 284000: 0.042420
# Loss after iteration 285000: 0.041462
# Loss after iteration 286000: 0.040626
# Loss after iteration 287000: 0.040225
# Loss after iteration 288000: 0.039920
# Loss after iteration 289000: 0.039656
# Loss after iteration 290000: 0.039431
# Loss after iteration 291000: 0.039237
# Loss after iteration 292000: 0.038800
# Loss after iteration 293000: 0.038341
# Loss after iteration 294000: 0.037954
# Loss after iteration 295000: 0.037705
# Loss after iteration 296000: 0.037186
# Loss after iteration 297000: 0.037034
# Loss after iteration 298000: 0.036822
# Loss after iteration 299000: 0.036546
# End of the trainning process

# %%
# Plot the decision boundary
plot_decision_boundary(lambda x: predict(model_Spiral, x))
plt.title("Decision Boundary for hidden layer size 8")
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 8')

# %%
pred_Spiral = predict(model_Spiralv2, X)
plotConfusionMatrix(y, pred_Spiral, classes = 2)
# Out:
# Accuracy: 99.7 %

# %% [markdown]
# with 300000 epohs and seed = 0 the model catch accuracy of 99.7 %

# %% [markdown]
# <a href="https://colab.research.google.com/github/JanLeyva/DeepLearning/blob/main/Copia_de_Assignment3Test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# # Assignment 3: Attention
#
# The objectives of this assignment are:
#
# + To implement Bahdanau Attention and Luong General Attention classes.
# + To do a comparative (# of steps to converge, test error) of the three methods we have seen. Use these values for the comparative (the training datset size and `rnn_units` and `batch_size` values are up to you):
#     + `n_timesteps_in = 100`
#     + `n_features = 20`.
# + To implement a function to visualize the attention weights for one example. You can visualize them as in this figure (that corresponds to a machine translation task):
#
# <div>
# <center>
# <img src="https://jalammar.github.io/images/attention_sentence.png" width="200">
# </center>
# </div>
#
# + To write a blog entry explaining in your words how does attention work. You can do it in your favourite blog site. If you do not have a favourite blog site, you can start one here: https://hackmd.io/
#
# You have to report all your work at the end of this notebook.

# %% [markdown]
# # Code

# %%
#@title Some utils
from random import randint
from matplotlib import pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

def generate_sequence(length, n_unique):
    """
    Generate a sequence of random integers.
    
    :length: Total length of the generated sequence
    :n_unique: Maximum number allowed
    """
    return [randint(1, n_unique-1) for _ in range(length)]

def one_hot_encode(sequence, n_unique):
    """
    Transform a sequence of integers into a one-hot-encoding vector
    
    :sequence: The sequence we want to transform
    :n_unique: Maximum number allowed (length of the one-hot-encoded vector)
    """
    encoding = list()
    for value in sequence:
        vector = [0 for _ in range(n_unique)]
        vector[value] = 1
        encoding.append(vector)
    return np.array(encoding)

def one_hot_decode(encoded_seq):
    """
    Transorm a one-hot-encoded vector into a list of integers
    
    :encoded_seq: One hot encoded sequence to be transformed
    """
    return [np.argmax(vector) for vector in encoded_seq]


def get_reversed_pairs(time_steps,vocabulary_size):
    """
    Generate a pair X, y where y is the 'reversed' version of X.
    
    :time_steps: Sequence length
    :vocabulary_size: Maximum number allowed
    """
    # generate random sequence and reverse it
    sequence_in = generate_sequence(time_steps, vocabulary_size)
    sequence_out = sequence_in[::-1]

    # one hot encode both sequences
    X = one_hot_encode(sequence_in, vocabulary_size)
    y = one_hot_encode(sequence_out, vocabulary_size)
    
    # reshape as 3D so it can be inputed to the LSTM
    X = X.reshape((1, X.shape[0], X.shape[1]))
    y = y.reshape((1, y.shape[0], y.shape[1]))
    return X,y


def create_dataset(train_size, test_size, time_steps,vocabulary_size):
    """
    Generates a datset of reversed pairs X, y.
    
    :train_size: Number of train pairs
    :test_size: Number of test pairs
    :time_steps: Sequence length
    :vocabulary_size: Maximum number allowed
    """
    
    # Generate reversed pairs for training
    pairs = [get_reversed_pairs(time_steps,vocabulary_size) for _ in range(train_size)]
    pairs= np.array(pairs).squeeze()
    X_train = pairs[:,0]
    y_train = pairs[:,1]
    
    # Generate reversed pairs for test
    pairs = [get_reversed_pairs(time_steps,vocabulary_size) for _ in range(test_size)]
    pairs= np.array(pairs).squeeze()
    X_test = pairs[:,0]
    y_test = pairs[:,1]	

    return X_train, y_train, X_test, y_test


def train_test(model, X_train, y_train , X_test, y_test, epochs=500, batch_size=32, patience=5):
    """
    It trains a model and evaluates the result on the test dataset
    
    :model: Model to be fit
    :X_train, y_train: Train samples and labels 
    :X_test y_test: Test samples and labels 
    :epochs: Maximum number of iterations that the model will perform
    :batch_size: Samples per batch
    :patience: Number of rounds without improvement that the model can perform. If there is no improvement on the loss, it will stop the trainning process.
    """
    
    # Train the model
    history=model.fit(X_train, y_train, 
                      validation_split= 0.1, 
                      epochs=epochs,
                      batch_size=batch_size, 
                      callbacks=[EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)])
    
    _, train_acc = model.evaluate(X_train, y_train, batch_size=batch_size)
    _, test_acc = model.evaluate(X_test, y_test, batch_size=batch_size)
    
    print('\nPREDICTION ACCURACY (%):')
    print('Train: %.3f, Test: %.3f' % (train_acc*100, test_acc*100))
    
    fig, axs = plt.subplots(1,2, figsize=(12,5))
    # summarize history for loss
    axs[0].plot(history.history['loss'])
    axs[0].plot(history.history['val_loss'])
    axs[0].set_title(model.name+' loss')
    axs[0].set_ylabel('loss')
    axs[0].set_xlabel('epoch')
    axs[0].legend(['train', 'val'], loc='upper left')
    
    # summarize history for accuracy
    axs[1].plot(history.history['accuracy'])
    axs[1].plot(history.history['val_accuracy'])
    axs[1].set_title(model.name+' accuracy')
    axs[1].set_ylabel('accuracy')
    axs[1].set_xlabel('epoch')
    axs[1].legend(['train', 'val'], loc='upper left')
    plt.show()
    
    
def predict(model, n_timesteps_in,n_features, x, y_real=None, batch_size = 1):
    pred=model.predict(x.reshape(1,n_timesteps_in,n_features), batch_size= batch_size)
    print('input', one_hot_decode(x))    
    print('predicted', one_hot_decode(pred[0]))
    if y_real is not None:
        print('expected', one_hot_decode(y_real))

# %%
# @title build_attention_model function

import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

tf.keras.backend.set_floatx('float64')

#attention model
def build_attention_model(attention, batch_size, rnn_units):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')
    decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense')
    
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = np.zeros((batch_size, 1, n_features))
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for _ in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states)
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        context_vector = tf.expand_dims(context_vector, 1)

        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model, encoder_lstm, decoder_lstm, decoder_dense

# %% [markdown]
# ## LuongDotAttention
#
# Luong Dot Attention score is defined by:
#
# $$score(h_t,\hat{h}_s)= h_t^T \hat{h}_s$$
#
# Notice that this attention function don't have training paramaters.

# %%
class LuongDotAttention(tf.keras.layers.Layer):
    def __init__(self):
        super(LuongDotAttention, self).__init__()

    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        values_transposed = tf.transpose(values, perm=[0, 2, 1])

        # LUONGH Dot-product
        score = tf.transpose(tf.matmul(query_with_time_axis, 
                                       values_transposed), perm=[0, 2, 1])

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %% [markdown]
# ### Defining parameters

# %%
# Assignment parameters
# dataset 
n_timesteps_in = 100  # Sequence length
n_features = 20     # Maximum number allowed-1 (length of the one-hot-encoded vector)
train_sizeA = 2000 
test_sizeA = 200
X_trainA, y_trainA, X_testA, y_testA = create_dataset(train_sizeA, test_sizeA, n_timesteps_in, n_features )

# %%
# training parameters
batch_sizeA = 100

# model parameters
rnn_unitsA = 100

# %% [markdown]
# ## Attention model - Luong Dot

# %%
# attention model
attentionA = LuongDotAttention()
model_attentionA, encoder_lstm, decoder_lstm, decoder_dense  = build_attention_model(attentionA, batch_sizeA, rnn_unitsA) 
# we need this encoder/decoder for the weight representation

# %% [markdown]
# ### Training model

# %%
train_test(model_attention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=5, patience=3)
# Out:
# Epoch 1/5
# 1800/1800 [==============================] - 63s 26ms/step - loss: 1.6039 - accuracy: 0.3675 - val_loss: 1.3365 - val_accuracy: 0.4150
# Epoch 2/5
# 1800/1800 [==============================] - 26s 15ms/step - loss: 1.2121 - accuracy: 0.4707 - val_loss: 1.1124 - val_accuracy: 0.5312
# Epoch 3/5
# 1800/1800 [==============================] - 26s 14ms/step - loss: 0.9207 - accuracy: 0.6224 - val_loss: 0.7795 - val_accuracy: 0.6825
# Epoch 4/5
# 1800/1800 [==============================] - 34s 19ms/step - loss: 0.5059 - accuracy: 0.8393 - val_loss: 0.3154 - val_accuracy: 0.9300
# Epoch 5/5
# 1800/1800 [==============================] - 41s 23ms/step - loss: 0.1821 - accuracy: 0.9712 - val_loss: 0.1214 - val_accuracy: 0.9900
# 2000/2000 [==============================] - 20s 10ms/step - loss: 0.1018 - accuracy: 0.9941
# 200/200 [==============================] - 2s 11ms/step - loss: 0.1272 - accuracy: 0.9850
#
# PREDICTION ACCURACY (%):
# Train: 99.413, Test: 98.500

# %%
# Assignment paramenters
train_test(model_attentionA, X_trainA, y_trainA , X_testA,
           y_testA, batch_size=batch_sizeA,epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 187s 5s/step - loss: 2.9617 - accuracy: 0.0529 - val_loss: 2.9467 - val_accuracy: 0.0527
# Epoch 2/50
# 18/18 [==============================] - 51s 3s/step - loss: 2.9454 - accuracy: 0.0540 - val_loss: 2.9435 - val_accuracy: 0.0543
# Epoch 3/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.9419 - accuracy: 0.0605 - val_loss: 2.9374 - val_accuracy: 0.0707
# Epoch 4/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.9342 - accuracy: 0.0690 - val_loss: 2.9299 - val_accuracy: 0.0718
# Epoch 5/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.9264 - accuracy: 0.0757 - val_loss: 2.9227 - val_accuracy: 0.0791
# Epoch 6/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.9194 - accuracy: 0.0802 - val_loss: 2.9164 - val_accuracy: 0.0824
# Epoch 7/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.9128 - accuracy: 0.0845 - val_loss: 2.9095 - val_accuracy: 0.0880
# Epoch 8/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.9056 - accuracy: 0.0878 - val_loss: 2.9019 - val_accuracy: 0.0882
# Epoch 9/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.8937 - accuracy: 0.0930 - val_loss: 2.8846 - val_accuracy: 0.0989
# Epoch 10/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.8767 - accuracy: 0.0996 - val_loss: 2.8690 - val_accuracy: 0.1018
# Epoch 11/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.8578 - accuracy: 0.1068 - val_loss: 2.8436 - val_accuracy: 0.1126
# Epoch 12/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.8232 - accuracy: 0.1183 - val_loss: 2.7962 - val_accuracy: 0.1266
# Epoch 13/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.7662 - accuracy: 0.1369 - val_loss: 2.7293 - val_accuracy: 0.1485
# Epoch 14/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.7099 - accuracy: 0.1524 - val_loss: 2.6749 - val_accuracy: 0.1646
# Epoch 15/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.6523 - accuracy: 0.1683 - val_loss: 2.6018 - val_accuracy: 0.1837
# Epoch 16/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.6595 - accuracy: 0.1662 - val_loss: 2.5902 - val_accuracy: 0.1846
# Epoch 17/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.5638 - accuracy: 0.1891 - val_loss: 2.5241 - val_accuracy: 0.1993
# Epoch 18/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.4966 - accuracy: 0.2051 - val_loss: 2.4621 - val_accuracy: 0.2119
# Epoch 19/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.4389 - accuracy: 0.2167 - val_loss: 2.3834 - val_accuracy: 0.2303
# Epoch 20/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.3898 - accuracy: 0.2269 - val_loss: 2.3952 - val_accuracy: 0.2284
# Epoch 21/50
# 18/18 [==============================] - 51s 3s/step - loss: 2.4405 - accuracy: 0.2159 - val_loss: 2.3597 - val_accuracy: 0.2346
# Epoch 22/50
# 18/18 [==============================] - 51s 3s/step - loss: 2.2958 - accuracy: 0.2487 - val_loss: 2.2591 - val_accuracy: 0.2566
# Epoch 23/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.2288 - accuracy: 0.2615 - val_loss: 2.1861 - val_accuracy: 0.2708
# Epoch 24/50
# 18/18 [==============================] - 49s 3s/step - loss: 2.1676 - accuracy: 0.2720 - val_loss: 2.1176 - val_accuracy: 0.2878
# Epoch 25/50
# 18/18 [==============================] - 49s 3s/step - loss: 2.1427 - accuracy: 0.2769 - val_loss: 2.1024 - val_accuracy: 0.2897
# Epoch 26/50
# 18/18 [==============================] - 49s 3s/step - loss: 2.1550 - accuracy: 0.2714 - val_loss: 2.5733 - val_accuracy: 0.1861
# Epoch 27/50
# 18/18 [==============================] - 49s 3s/step - loss: 2.2885 - accuracy: 0.2443 - val_loss: 2.0795 - val_accuracy: 0.2935
# Epoch 28/50
# 18/18 [==============================] - 49s 3s/step - loss: 2.0184 - accuracy: 0.3033 - val_loss: 2.0300 - val_accuracy: 0.2962
# Epoch 29/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.9660 - accuracy: 0.3110 - val_loss: 1.8967 - val_accuracy: 0.3288
# Epoch 30/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.8815 - accuracy: 0.3313 - val_loss: 1.9625 - val_accuracy: 0.3065
# Epoch 31/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.9557 - accuracy: 0.3113 - val_loss: 1.8643 - val_accuracy: 0.3328
# Epoch 32/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.8916 - accuracy: 0.3231 - val_loss: 1.7976 - val_accuracy: 0.3453
# Epoch 33/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.7871 - accuracy: 0.3499 - val_loss: 1.7323 - val_accuracy: 0.3631
# Epoch 34/50
# 18/18 [==============================] - 50s 3s/step - loss: 1.7205 - accuracy: 0.3670 - val_loss: 1.7948 - val_accuracy: 0.3464
# Epoch 35/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.8207 - accuracy: 0.3363 - val_loss: 1.7434 - val_accuracy: 0.3631
# Epoch 36/50
# 18/18 [==============================] - 50s 3s/step - loss: 1.7050 - accuracy: 0.3675 - val_loss: 1.6164 - val_accuracy: 0.3892
# Epoch 37/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.6069 - accuracy: 0.3959 - val_loss: 1.5917 - val_accuracy: 0.4016
# Epoch 38/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.5645 - accuracy: 0.4071 - val_loss: 1.5619 - val_accuracy: 0.4041
# Epoch 39/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.5211 - accuracy: 0.4229 - val_loss: 1.4837 - val_accuracy: 0.4304
# Epoch 40/50
# 18/18 [==============================] - 50s 3s/step - loss: 1.5134 - accuracy: 0.4227 - val_loss: 1.4239 - val_accuracy: 0.4541
# Epoch 41/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.4659 - accuracy: 0.4364 - val_loss: 1.3679 - val_accuracy: 0.4749
# Epoch 42/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.4130 - accuracy: 0.4552 - val_loss: 1.3360 - val_accuracy: 0.4884
# Epoch 43/50
# 18/18 [==============================] - 49s 3s/step - loss: 1.3857 - accuracy: 0.4638 - val_loss: 1.5970 - val_accuracy: 0.3811
# Epoch 44/50
# 18/18 [==============================] - 50s 3s/step - loss: 1.5738 - accuracy: 0.4023 - val_loss: 2.1634 - val_accuracy: 0.2549
# Epoch 45/50
# 18/18 [==============================] - 50s 3s/step - loss: 2.8985 - accuracy: 0.1520 - val_loss: 2.6281 - val_accuracy: 0.1797
# 20/20 [==============================] - 17s 835ms/step - loss: 1.3115 - accuracy: 0.4993
# 2/2 [==============================] - 2s 810ms/step - loss: 1.3352 - accuracy: 0.4908
#
# PREDICTION ACCURACY (%):
# Train: 49.930, Test: 49.080

# %% [markdown]
# * Test with:
# - Batch = 1
# - RNN = 1

# %%
# training parameters
batch_sizeA = 10

# model parameters
rnn_unitsA = 10


# attention model
attentionA = LuongDotAttention()
model_attentionA, encoder_lstm, decoder_lstm, decoder_dense  = build_attention_model(attentionA, batch_sizeA, rnn_unitsA) 
# we need this encoder/decoder for the weight representation


attentionb = LuongDotAttention()
model_attentionB, encoder_lstm, decoder_lstm, decoder_dense  = build_attention_model(attentionA, batch_sizeA, rnn_unitsA) 
# Assignment paramenters
train_test(model_attentionB, X_trainA, y_trainA , X_testA,
           y_testA, batch_size=batch_sizeA, epochs=50, patience=3)

# %% [markdown]
# ### Prediction
# * Test parameters

# %%
Xtest = one_hot_encode(np.array([1,2,3,4]), n_features)
predict(model_attention, n_timesteps_in, n_features, Xtest)
# Out:
# input [1, 2, 3, 4]
# predicted [4, 3, 1, 1]

# %%
one_hot_decode(X_test[0])
# Out:
# [1, 8, 1, 5]

# %%
predict(model_attention, n_timesteps_in, n_features, X_test[0])
# Out:
# input [1, 8, 1, 5]
# predicted [5, 1, 8, 1]

# %%
predict(model_attention, n_timesteps_in, n_features, X_test[1])
# Out:
# input [4, 9, 7, 7]
# predicted [7, 7, 9, 4]

# %% [markdown]
# * Assignment parameters

# %%
predict(model_attentionA, n_timesteps_in, n_features, X_testA[0])
# Out:
# input [8, 14, 11, 14, 15, 16, 6, 5, 15, 18, 13, 19, 11, 5, 3, 15, 13, 4, 19, 15, 1, 12, 3, 12, 12, 3, 2, 15, 5, 5, 14, 16, 19, 7, 10, 12, 14, 15, 13, 8, 10, 4, 12, 11, 16, 5, 14, 6, 17, 19, 19, 16, 11, 3, 17, 4, 8, 3, 1, 7, 15, 8, 16, 12, 5, 9, 3, 17, 2, 14, 6, 15, 5, 18, 9, 12, 16, 4, 4, 19, 6, 16, 5, 6, 11, 13, 10, 12, 6, 4, 11, 9, 12, 18, 8, 14, 3, 10, 15, 14]
# predicted [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]

# %%
predict(model_attentionB, n_timesteps_in, n_features, X_testA[0])
# Out:
# input [6, 10, 4, 6, 11, 14, 19, 6, 12, 6, 18, 6, 9, 10, 6, 12, 15, 14, 10, 4, 5, 19, 17, 6, 8, 18, 4, 13, 19, 10, 9, 4, 11, 4, 19, 10, 5, 13, 16, 19, 5, 13, 9, 3, 19, 6, 17, 17, 18, 17, 7, 12, 6, 4, 12, 2, 19, 1, 13, 6, 7, 4, 18, 8, 10, 7, 4, 1, 3, 13, 15, 14, 13, 12, 15, 10, 9, 17, 17, 10, 18, 13, 4, 19, 19, 5, 14, 19, 14, 11, 4, 18, 7, 13, 2, 6, 7, 7, 15, 1]
# predicted [19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19]

# %% [markdown]
# ### Visualization the Weight
#
# #### function to Plot Weight
#
# The idea is take the `build_function` and modify in order to get the `attention_weightPlot` and the `input_seq` and `out_seq`. For do that we need to take into account the following from our model:
# * `attention`: the Attention function (LuongDot, LuongGeneral, Bahdanau).
# * `encoder_lstm`: encoder used
# * `decoder_lstm`: decoder used
# * `decoder_dense`: decoder used

# %%
 #@title function to Compute and Plot the weight
# function to Compute and Plot the weight

import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K



def build_attention_weight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    #encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    #encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    attention_plot = np.zeros((n_timesteps_in, n_timesteps_in))
    sequence = one_hot_encode(seq_in,n_features)

    encoder_inputs=np.array(sequence).reshape(1,n_timesteps_in,n_features)
    encoder_inputs = tf.convert_to_tensor(encoder_inputs,dtype=tf.float32)

    # Def encoder_lstm
    #encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm') <--------- Usamos los entrenados
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    #decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')        # <--------- Usamos los entrenados
    #decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense') # <--------- Usamos los entrenados
    decoder_input_data = np.zeros((1, 1, n_features))
    decoder_input_data[:, 0, 0] = 1 
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = decoder_input_data
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for i in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states) <---------
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[i] = attention_weights.numpy()
        #context_vector = tf.expand_dims(context_vector, 1) <---------

        decoder_outputs=tf.expand_dims(decoder_outputs, 1)

        context_vector = tf.expand_dims(context_vector, 1)


        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)      
        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    seq_out=one_hot_decode(decoder_outputs[0])  # <---------

    
    #model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')  <---------
    #model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) <---------
    
    return seq_in, seq_out, attention_plot

# %% [markdown]
# ### Plot attention function

# %%
from matplotlib import ticker

def plot_attention(attention, sequence, predicted_sequence):
  fig = plt.figure(figsize=(8,8))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sequence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sequence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()


def plotWeight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense):
  seq_in, seq_out, attention_plot = build_attention_weight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense)

  print('Input: %s' % (seq_in))
  print('Predicted translation: {}'.format(seq_out))

  attention_plot = attention_plot[:len(seq_out), :len(seq_in)]
  plot_attention(attention_plot, seq_in, seq_out)

# %% [markdown]
# lo hace fatal!! porque? no esta cogiendo el encoder decoder trained. ni los attention weight antes encontrados.

# %%
plotWeight(one_hot_decode(X_testA[0]), attentionA, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [6, 10, 4, 6, 11, 14, 19, 6, 12, 6, 18, 6, 9, 10, 6, 12, 15, 14, 10, 4, 5, 19, 17, 6, 8, 18, 4, 13, 19, 10, 9, 4, 11, 4, 19, 10, 5, 13, 16, 19, 5, 13, 9, 3, 19, 6, 17, 17, 18, 17, 7, 12, 6, 4, 12, 2, 19, 1, 13, 6, 7, 4, 18, 8, 10, 7, 4, 1, 3, 13, 15, 14, 13, 12, 15, 10, 9, 17, 17, 10, 18, 13, 4, 19, 19, 5, 14, 19, 14, 11, 4, 18, 7, 13, 2, 6, 7, 7, 15, 1]
# Predicted translation: [19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19]

# %%
plotWeight([9,2,3,4], attention, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [9, 2, 3, 4]
# Predicted translation: [4, 3, 2, 9]

# %%
plotWeight([1,2,3,4], attention, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [1, 2, 3, 4]
# Predicted translation: [4, 3, 1, 1]

# %% [markdown]
# # BahdanauAttention
#
# Bahdanau attention function is defined by:
#
# $$ score(h_t, \hat{h}_s)=V^Ttanh(W_a[h_t:\hat{h}_s])$$

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values

    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
# attention model
attentionBahdanauAttention = BahdanauAttention(16)
model_attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah = build_attention_model(attentionBahdanauAttention, batch_size, rnn_units)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0e63fd089596> in <module>()
#       1 # attention model
#       2 attentionBahdanauAttention = BahdanauAttention(100)
# ----> 3 model_attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah = build_attention_model(attentionBahdanauAttention, batch_size, rnn_units)
#
# NameError: name 'batch_size' is not defined

# %%
train_test(model_attentionBahdanauAttention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=2, patience=3)
# Out:
# Epoch 1/2
# 1800/1800 [==============================] - 42s 18ms/step - loss: 1.6644 - accuracy: 0.3565 - val_loss: 1.3431 - val_accuracy: 0.4338
# Epoch 2/2
# 1800/1800 [==============================] - 29s 16ms/step - loss: 1.1475 - accuracy: 0.5251 - val_loss: 0.7987 - val_accuracy: 0.7375
# 2000/2000 [==============================] - 16s 8ms/step - loss: 0.7913 - accuracy: 0.7456
# 200/200 [==============================] - 1s 7ms/step - loss: 0.8149 - accuracy: 0.7300
#
# PREDICTION ACCURACY (%):
# Train: 74.562, Test: 73.000

# %% [markdown]
# # with assignment parameters

# %%
# attention model
attentionBahdanauAttentionA = BahdanauAttention(100)
model_attentionBahdanauAttentionA, encoder_lstmBah, decoder_lstmBah, decoder_denseBah = build_attention_model(attentionBahdanauAttentionA, batch_sizeA, rnn_unitsA)

# %%
train_test(model_attentionBahdanauAttentionA, X_trainA, y_trainA , X_testA,
           y_testA, batch_size=batch_sizeA,epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 222s 4s/step - loss: 2.9656 - accuracy: 0.0540 - val_loss: 2.9467 - val_accuracy: 0.0616
# Epoch 2/50
# 18/18 [==============================] - 14s 769ms/step - loss: 2.9445 - accuracy: 0.0588 - val_loss: 2.9426 - val_accuracy: 0.0549
# Epoch 3/50
# 18/18 [==============================] - 14s 764ms/step - loss: 2.9395 - accuracy: 0.0635 - val_loss: 2.9355 - val_accuracy: 0.0614
# Epoch 4/50
# 18/18 [==============================] - 14s 754ms/step - loss: 2.9313 - accuracy: 0.0706 - val_loss: 2.9260 - val_accuracy: 0.0723
# Epoch 5/50
# 18/18 [==============================] - 14s 753ms/step - loss: 2.9230 - accuracy: 0.0773 - val_loss: 2.9236 - val_accuracy: 0.0764
# Epoch 6/50
# 18/18 [==============================] - 14s 763ms/step - loss: 2.9145 - accuracy: 0.0823 - val_loss: 2.9175 - val_accuracy: 0.0816
# Epoch 7/50
# 18/18 [==============================] - 14s 756ms/step - loss: 2.9080 - accuracy: 0.0860 - val_loss: 2.9044 - val_accuracy: 0.0857
# Epoch 8/50
# 18/18 [==============================] - 14s 755ms/step - loss: 2.8982 - accuracy: 0.0904 - val_loss: 2.8954 - val_accuracy: 0.0917
# Epoch 9/50
# 18/18 [==============================] - 14s 752ms/step - loss: 2.8904 - accuracy: 0.0943 - val_loss: 2.8904 - val_accuracy: 0.0939
# Epoch 10/50
# 18/18 [==============================] - 13s 751ms/step - loss: 2.8832 - accuracy: 0.0964 - val_loss: 2.8805 - val_accuracy: 0.0984
# Epoch 11/50
# 18/18 [==============================] - 14s 764ms/step - loss: 2.8759 - accuracy: 0.0989 - val_loss: 2.8744 - val_accuracy: 0.0975
# Epoch 12/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.8691 - accuracy: 0.1012 - val_loss: 2.8656 - val_accuracy: 0.1013
# Epoch 13/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.8585 - accuracy: 0.1044 - val_loss: 2.8492 - val_accuracy: 0.1056
# Epoch 14/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.8369 - accuracy: 0.1125 - val_loss: 2.8291 - val_accuracy: 0.1145
# Epoch 15/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.8001 - accuracy: 0.1247 - val_loss: 2.7659 - val_accuracy: 0.1399
# Epoch 16/50
# 18/18 [==============================] - 14s 756ms/step - loss: 2.7446 - accuracy: 0.1429 - val_loss: 2.7168 - val_accuracy: 0.1510
# Epoch 17/50
# 18/18 [==============================] - 14s 768ms/step - loss: 2.6981 - accuracy: 0.1561 - val_loss: 2.7115 - val_accuracy: 0.1531
# Epoch 18/50
# 18/18 [==============================] - 14s 767ms/step - loss: 2.6429 - accuracy: 0.1706 - val_loss: 2.6043 - val_accuracy: 0.1787
# Epoch 19/50
# 18/18 [==============================] - 14s 757ms/step - loss: 2.5721 - accuracy: 0.1870 - val_loss: 2.5089 - val_accuracy: 0.2018
# Epoch 20/50
# 18/18 [==============================] - 14s 754ms/step - loss: 2.5380 - accuracy: 0.1943 - val_loss: 2.4769 - val_accuracy: 0.2089
# Epoch 21/50
# 18/18 [==============================] - 13s 751ms/step - loss: 2.4933 - accuracy: 0.2038 - val_loss: 2.4735 - val_accuracy: 0.2097
# Epoch 22/50
# 18/18 [==============================] - 14s 754ms/step - loss: 2.4028 - accuracy: 0.2276 - val_loss: 2.4595 - val_accuracy: 0.2082
# Epoch 23/50
# 18/18 [==============================] - 14s 752ms/step - loss: 2.3780 - accuracy: 0.2294 - val_loss: 2.2922 - val_accuracy: 0.2505
# Epoch 24/50
# 18/18 [==============================] - 14s 753ms/step - loss: 2.4230 - accuracy: 0.2162 - val_loss: 2.3706 - val_accuracy: 0.2283
# Epoch 25/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.2765 - accuracy: 0.2522 - val_loss: 2.4287 - val_accuracy: 0.2054
# Epoch 26/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.2542 - accuracy: 0.2518 - val_loss: 2.1494 - val_accuracy: 0.2783
# Epoch 27/50
# 18/18 [==============================] - 14s 756ms/step - loss: 2.1481 - accuracy: 0.2773 - val_loss: 2.0580 - val_accuracy: 0.2993
# Epoch 28/50
# 18/18 [==============================] - 14s 756ms/step - loss: 2.0755 - accuracy: 0.2924 - val_loss: 1.9985 - val_accuracy: 0.3115
# Epoch 29/50
# 18/18 [==============================] - 14s 755ms/step - loss: 2.0354 - accuracy: 0.2984 - val_loss: 1.9683 - val_accuracy: 0.3169
# Epoch 30/50
# 18/18 [==============================] - 14s 753ms/step - loss: 2.3951 - accuracy: 0.2313 - val_loss: 2.3752 - val_accuracy: 0.2336
# Epoch 31/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.2729 - accuracy: 0.2610 - val_loss: 2.1044 - val_accuracy: 0.3030
# Epoch 32/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.0692 - accuracy: 0.3023 - val_loss: 2.1039 - val_accuracy: 0.2848
# 20/20 [==============================] - 5s 233ms/step - loss: 1.9619 - accuracy: 0.3192
# 2/2 [==============================] - 0s 241ms/step - loss: 1.9665 - accuracy: 0.3204
#
# PREDICTION ACCURACY (%):
# Train: 31.920, Test: 32.040

# %% [markdown]
# ## Predict

# %% [markdown]
# ## Lets try to predict with batch size = 100

# %%
predict(model_attentionBahdanauAttention, n_timesteps_in, n_features, X_test[0])
# Out:
# input [9, 5, 2, 8]
# predicted [8, 2, 5, 9]

# %%
predict(model_attentionBahdanauAttention, n_timesteps_in, n_features, X_test[1])
# Out:
# input [4, 9, 7, 7]
# predicted [7, 7, 9, 4]

# %%
plotWeight([9, 5, 2, 8], attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah)
# Out:
# Input: [9, 5, 2, 8]
# Predicted translation: [8, 2, 5, 9]

# %%
plotWeight([1, 8, 1, 5], attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah)
# Out:
# Input: [1, 8, 1, 5]
# Predicted translation: [1, 1, 1, 1]

# %% [markdown]
# # LuongGeneralAttention
#
# Luong General Attention function is defined by:
#
# $$score(h_t,\hat{h}_s)= h_t^T W_a\hat{h}_s$$

# %%
class LuongGeneralAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(LuongGeneralAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)


    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        values_transposed = tf.transpose(values, perm=[0, 2, 1])

        # LUONGH Dot-product
        score = tf.transpose(tf.matmul(query_with_time_axis, 
                                       self.W1(values_transposed)), perm=[0, 2, 1])

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
# attention model
attentionLuongGeneral = LuongGeneralAttention(units = 1)
model_attentionLuongGeneral, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen = build_attention_model(attentionLuongGeneral, batch_size, rnn_units)


#training
train_test(model_attentionLuongGeneral, X_train, y_train , X_test,
           y_test, batch_size=batch_size, epochs=5, patience=3)
# Out:
# Epoch 1/5
# 1800/1800 [==============================] - 36s 16ms/step - loss: 1.5732 - accuracy: 0.3651 - val_loss: 1.2929 - val_accuracy: 0.4363
# Epoch 2/5
# 1800/1800 [==============================] - 27s 15ms/step - loss: 1.1936 - accuracy: 0.4769 - val_loss: 1.0479 - val_accuracy: 0.5475
# Epoch 3/5
# 1800/1800 [==============================] - 26s 15ms/step - loss: 0.9437 - accuracy: 0.6089 - val_loss: 0.7989 - val_accuracy: 0.6925
# Epoch 4/5
# 1800/1800 [==============================] - 28s 16ms/step - loss: 0.6734 - accuracy: 0.7369 - val_loss: 0.5217 - val_accuracy: 0.8075
# Epoch 5/5
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.4010 - accuracy: 0.8729 - val_loss: 0.2735 - val_accuracy: 0.9287
# 2000/2000 [==============================] - 21s 10ms/step - loss: 0.2701 - accuracy: 0.9324
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2939 - accuracy: 0.9087
#
# PREDICTION ACCURACY (%):
# Train: 93.237, Test: 90.875

# %% [markdown]
# ## with assignment parameters

# %%
# attention model
attentionLuongGeneralA = LuongGeneralAttention(units = 100)
model_attentionLuongGeneralA, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen = build_attention_model(attentionLuongGeneralA, batch_sizeA, rnn_unitsA)


#training
train_test(model_attentionLuongGeneralA, X_trainA, y_trainA , X_testA,
           y_testA, batch_size=batch_sizeA, epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 224s 4s/step - loss: 2.9651 - accuracy: 0.0549 - val_loss: 2.9469 - val_accuracy: 0.0539
# Epoch 2/50
# 18/18 [==============================] - 13s 715ms/step - loss: 2.9451 - accuracy: 0.0557 - val_loss: 2.9438 - val_accuracy: 0.0532
# Epoch 3/50
# 18/18 [==============================] - 13s 697ms/step - loss: 2.9417 - accuracy: 0.0628 - val_loss: 2.9389 - val_accuracy: 0.0665
# Epoch 4/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.9340 - accuracy: 0.0725 - val_loss: 2.9315 - val_accuracy: 0.0756
# Epoch 5/50
# 18/18 [==============================] - 12s 694ms/step - loss: 2.9250 - accuracy: 0.0783 - val_loss: 2.9208 - val_accuracy: 0.0786
# Epoch 6/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.9157 - accuracy: 0.0823 - val_loss: 2.9156 - val_accuracy: 0.0837
# Epoch 7/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.9065 - accuracy: 0.0871 - val_loss: 2.9019 - val_accuracy: 0.0869
# Epoch 8/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.8860 - accuracy: 0.0954 - val_loss: 2.8696 - val_accuracy: 0.1003
# Epoch 9/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.8537 - accuracy: 0.1064 - val_loss: 2.8333 - val_accuracy: 0.1144
# Epoch 10/50
# 18/18 [==============================] - 12s 694ms/step - loss: 2.8188 - accuracy: 0.1185 - val_loss: 2.7934 - val_accuracy: 0.1319
# Epoch 11/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.7702 - accuracy: 0.1351 - val_loss: 2.7456 - val_accuracy: 0.1424
# Epoch 12/50
# 18/18 [==============================] - 12s 693ms/step - loss: 2.7079 - accuracy: 0.1517 - val_loss: 2.6762 - val_accuracy: 0.1588
# Epoch 13/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.6547 - accuracy: 0.1655 - val_loss: 2.6389 - val_accuracy: 0.1721
# Epoch 14/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.6091 - accuracy: 0.1756 - val_loss: 2.5639 - val_accuracy: 0.1850
# Epoch 15/50
# 18/18 [==============================] - 12s 693ms/step - loss: 2.5363 - accuracy: 0.1913 - val_loss: 2.5059 - val_accuracy: 0.2000
# Epoch 16/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.4896 - accuracy: 0.2011 - val_loss: 2.4565 - val_accuracy: 0.2078
# Epoch 17/50
# 18/18 [==============================] - 12s 679ms/step - loss: 2.4464 - accuracy: 0.2092 - val_loss: 2.4142 - val_accuracy: 0.2167
# Epoch 18/50
# 18/18 [==============================] - 12s 693ms/step - loss: 2.3919 - accuracy: 0.2195 - val_loss: 2.3630 - val_accuracy: 0.2253
# Epoch 19/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.3714 - accuracy: 0.2223 - val_loss: 2.3879 - val_accuracy: 0.2167
# Epoch 20/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.3361 - accuracy: 0.2294 - val_loss: 2.3581 - val_accuracy: 0.2212
# Epoch 21/50
# 18/18 [==============================] - 12s 679ms/step - loss: 2.3108 - accuracy: 0.2326 - val_loss: 2.2978 - val_accuracy: 0.2354
# Epoch 22/50
# 18/18 [==============================] - 12s 679ms/step - loss: 2.2572 - accuracy: 0.2428 - val_loss: 2.2441 - val_accuracy: 0.2424
# Epoch 23/50
# 18/18 [==============================] - 12s 678ms/step - loss: 2.2370 - accuracy: 0.2461 - val_loss: 2.2207 - val_accuracy: 0.2485
# Epoch 24/50
# 18/18 [==============================] - 12s 692ms/step - loss: 2.2093 - accuracy: 0.2506 - val_loss: 2.2076 - val_accuracy: 0.2471
# Epoch 25/50
# 18/18 [==============================] - 12s 679ms/step - loss: 2.2008 - accuracy: 0.2516 - val_loss: 2.3527 - val_accuracy: 0.2223
# Epoch 26/50
# 18/18 [==============================] - 12s 692ms/step - loss: 2.2906 - accuracy: 0.2315 - val_loss: 2.2169 - val_accuracy: 0.2425
# Epoch 27/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.1751 - accuracy: 0.2544 - val_loss: 2.1618 - val_accuracy: 0.2563
# Epoch 28/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.1357 - accuracy: 0.2633 - val_loss: 2.1427 - val_accuracy: 0.2574
# Epoch 29/50
# 18/18 [==============================] - 12s 692ms/step - loss: 2.1167 - accuracy: 0.2634 - val_loss: 2.0994 - val_accuracy: 0.2676
# Epoch 30/50
# 18/18 [==============================] - 12s 693ms/step - loss: 2.0842 - accuracy: 0.2717 - val_loss: 2.0789 - val_accuracy: 0.2727
# Epoch 31/50
# 18/18 [==============================] - 12s 693ms/step - loss: 2.0521 - accuracy: 0.2800 - val_loss: 2.0740 - val_accuracy: 0.2732
# Epoch 32/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.0482 - accuracy: 0.2778 - val_loss: 2.0596 - val_accuracy: 0.2691
# Epoch 33/50
# 18/18 [==============================] - 12s 692ms/step - loss: 2.0233 - accuracy: 0.2836 - val_loss: 2.0157 - val_accuracy: 0.2878
# Epoch 34/50
# 18/18 [==============================] - 12s 693ms/step - loss: 2.0121 - accuracy: 0.2855 - val_loss: 2.2008 - val_accuracy: 0.2334
# Epoch 35/50
# 18/18 [==============================] - 12s 693ms/step - loss: 2.0481 - accuracy: 0.2746 - val_loss: 2.0227 - val_accuracy: 0.2769
# Epoch 36/50
# 18/18 [==============================] - 12s 676ms/step - loss: 1.9769 - accuracy: 0.2939 - val_loss: 1.9723 - val_accuracy: 0.2928
# Epoch 37/50
# 18/18 [==============================] - 12s 679ms/step - loss: 1.9402 - accuracy: 0.3044 - val_loss: 2.0343 - val_accuracy: 0.2671
# Epoch 38/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.1881 - accuracy: 0.2453 - val_loss: 2.1863 - val_accuracy: 0.2551
# Epoch 39/50
# 18/18 [==============================] - 12s 681ms/step - loss: 2.0354 - accuracy: 0.2795 - val_loss: 2.0041 - val_accuracy: 0.2789
# 20/20 [==============================] - 4s 197ms/step - loss: 1.9542 - accuracy: 0.2983
# 2/2 [==============================] - 0s 202ms/step - loss: 1.9793 - accuracy: 0.2878
#
# PREDICTION ACCURACY (%):
# Train: 29.828, Test: 28.785

# %% [markdown]
# Esto funciona teniendo:
# Dataset formado por
# - n_timesteps_in = 100
# - n_features = 20
# - batch_size = 100
# - rnn_units = 100
#
# **El tema esta en tenir la mateixa rnn_units i batch_size**

# %% [markdown]
# # vamos a probar de predecir
# a priori no deberia funcionar debido al batch_size

# %%
predict(model_attentionLuongGeneral, n_timesteps_in, n_features, one_hot_encode([1,2,3,4], 10))
# Out:
# input [1, 2, 3, 4]
# predicted [4, 3, 2, 1]

# %%
predict(model_attentionLuongGeneral, n_timesteps_in, n_features, X_test[0])
# Out:
# input [6, 5, 8, 1]
# predicted [1, 8, 5, 6]

# %% [markdown]
# # Visualize the weight

# %%
plotWeight([1, 2, 3, 4], attentionBahdanauAttention, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen)
# Out:
# Input: [1, 2, 3, 4]
# Predicted translation: [4, 6, 2, 1]

# %%
plotWeight([1, 8, 1, 5], attentionBahdanauAttention, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen)
# Out:
# Input: [1, 8, 1, 5]
# Predicted translation: [5, 1, 1, 1]

# %% [markdown]
# # Visualize the Weight

# %%
 #@title function to Compute and Plot the weight
# function to Compute and Plot the weight

import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K



def build_attention_weight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    #encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    #encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    attention_plot = np.zeros((n_timesteps_in, n_timesteps_in))
    sequence = one_hot_encode(seq_in,n_features)

    encoder_inputs=np.array(sequence).reshape(1,n_timesteps_in,n_features)
    encoder_inputs = tf.convert_to_tensor(encoder_inputs,dtype=tf.float32)

    # Def encoder_lstm
    #encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm') <--------- Usamos los entrenados
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    #decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')        # <--------- Usamos los entrenados
    #decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense') # <--------- Usamos los entrenados
    decoder_input_data = np.zeros((1, 1, n_features))
    decoder_input_data[:, 0, 0] = 1 
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = decoder_input_data
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for i in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states) <---------
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[i] = attention_weights.numpy()
        #context_vector = tf.expand_dims(context_vector, 1) <---------

        decoder_outputs=tf.expand_dims(decoder_outputs, 1)

        context_vector = tf.expand_dims(context_vector, 1)


        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)      
        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    seq_out=one_hot_decode(decoder_outputs[0])  # <---------

    
    #model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')  <---------
    #model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) <---------
    
    return seq_in, seq_out, attention_plot

# %% [markdown]
# ### Plot attention weight function

# %%
from matplotlib import ticker
import seaborn as sns

def plot_attention(attention, sequence, predicted_sequence, weight_n = True):
  """ 
  attention: the attention function used to calc the weight
  if weight_n = True the weight number will appears, else not.
  """
  fig = plt.figure(figsize=(8,8))
  ax = fig.add_subplot(1, 1, 1)
  ax = sns.heatmap(attention, annot=weight_n, \
                     fmt='.2g', cmap='gist_gray')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sequence, fontdict=fontdict, rotation=45)
  ax.set_yticklabels([''] + predicted_sequence, rotation = 45, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()


def plotWeight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense, weight_n = True):
  seq_in, seq_out, attention_plot = build_attention_weight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense)

  print('Input: %s' % (seq_in))
  print('Predicted: {}'.format(seq_out))

  attention_plot = attention_plot[:len(seq_out), :len(seq_in)]
  plot_attention(attention_plot, seq_in, seq_out, weight_n)

# %%
def plotWeight_(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense):
  seq_in, seq_out, attention_plot = build_attention_weight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense)

  print('Input: %s' % (seq_in))
  print('Predicted: {}'.format(seq_out))

  #attention_plot = attention_plot[:len(seq_out), :len(seq_in)]
  #plot_attention(attention_plot, seq_in, seq_out)
  return attention_plot, seq_in, seq_out, attention_plot

# %%
sns.heatmap(attention_plotT, annot=True, \
                     fmt='.2g', cmap='gist_gray')

# %%
def plot_attention_(attention, sequence, predicted_sequence, weight_n = True):
  fig = plt.figure(figsize=(8,8))
  ax = fig.add_subplot(1, 1, 1)
  ax = sns.heatmap(attention_plotT, annot=weight_n, \
                     fmt='.2g', cmap='gist_gray')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sequence, fontdict=fontdict, rotation=45)
  ax.set_yticklabels([''] + predicted_sequence, rotation = 45, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
plot_attention_(attention_plotT, [1,2,3,4], [4,3,2,1])

# %% [markdown]
# ### Example dataset:
# In order to see propertly the weight in a heatplot we will use a small dataset reducing the number of times step and number of features.
# - n_timesteps_in = 4
# - n_features = 10
# - train_size = 2000
# - test_size = 200

# %%
#@title changed part n_timesteps_in, n_features
# dataset 
n_timesteps_in = 4  # Sequence length                                                 ## changed from 100 to 4
n_features = 10     # Maximum number allowed-1 (length of the one-hot-encoded vector) ## changed from 20 to 10
train_size = 2000 
test_size = 200
X_train, y_train, X_test, y_test = create_dataset(train_size, test_size, n_timesteps_in,n_features)

# training parameters
batch_size = 1

# model parameters
rnn_units = 16       # changed from 100 to 16

# %% [markdown]
# # Luong Dot Attention

# %%
# attention model
attention = LuongDotAttention()
model_attention, encoder_lstm, decoder_lstm, decoder_dense  = build_attention_model(attention, batch_size, rnn_units) 
# we need this encoder/decoder for the weight representation

train_test(model_attention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=7, patience=3)
# Out:
# Epoch 1/7
# 1800/1800 [==============================] - 49s 20ms/step - loss: 1.6396 - accuracy: 0.3568 - val_loss: 1.3515 - val_accuracy: 0.4213
# Epoch 2/7
# 1800/1800 [==============================] - 26s 15ms/step - loss: 1.2763 - accuracy: 0.4412 - val_loss: 1.1455 - val_accuracy: 0.4988
# Epoch 3/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 1.0495 - accuracy: 0.5490 - val_loss: 0.8982 - val_accuracy: 0.6312
# Epoch 4/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.7314 - accuracy: 0.7285 - val_loss: 0.5385 - val_accuracy: 0.8250
# Epoch 5/7
# 1800/1800 [==============================] - 26s 15ms/step - loss: 0.3295 - accuracy: 0.9182 - val_loss: 0.2223 - val_accuracy: 0.9537
# Epoch 6/7
# 1800/1800 [==============================] - 26s 15ms/step - loss: 0.1353 - accuracy: 0.9804 - val_loss: 0.1116 - val_accuracy: 0.9850
# Epoch 7/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.0811 - accuracy: 0.9894 - val_loss: 0.0616 - val_accuracy: 0.9925
# 2000/2000 [==============================] - 14s 7ms/step - loss: 0.0540 - accuracy: 0.9944
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0632 - accuracy: 0.9950
#
# PREDICTION ACCURACY (%):
# Train: 99.438, Test: 99.500

# %%
plotWeight([1,2,3,4], attention, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [1, 2, 3, 4]
# Predicted translation: [4, 3, 2, 1]

# %%
plotWeight([1,2,3,4], attention, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [1, 2, 3, 4]
# Predicted: [4, 3, 2, 1]

# %%
plotWeight([9,2,3,9], attention, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [9, 2, 3, 9]
# Predicted: [9, 3, 9, 9]

# %% [markdown]
# # Banhdanau Attention

# %%
# attention model
attentionBahdanauAttention = BahdanauAttention(16)
model_attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah = build_attention_model(attentionBahdanauAttention, batch_size, rnn_units)

train_test(model_attentionBahdanauAttention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=7, patience=3)
# Out:
# Epoch 1/7
# 1800/1800 [==============================] - 40s 18ms/step - loss: 1.6157 - accuracy: 0.3828 - val_loss: 1.2836 - val_accuracy: 0.4600
# Epoch 2/7
# 1800/1800 [==============================] - 30s 16ms/step - loss: 1.0208 - accuracy: 0.5999 - val_loss: 0.4587 - val_accuracy: 0.9038
# Epoch 3/7
# 1800/1800 [==============================] - 29s 16ms/step - loss: 0.1412 - accuracy: 0.9912 - val_loss: 0.0491 - val_accuracy: 0.9962
# Epoch 4/7
# 1800/1800 [==============================] - 31s 17ms/step - loss: 0.0208 - accuracy: 0.9996 - val_loss: 0.1214 - val_accuracy: 0.9613
# Epoch 5/7
# 1800/1800 [==============================] - 32s 18ms/step - loss: 0.0155 - accuracy: 0.9982 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 6/7
# 1800/1800 [==============================] - 31s 17ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 7/7
# 1800/1800 [==============================] - 32s 18ms/step - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.1076 - val_accuracy: 0.9788
# 2000/2000 [==============================] - 16s 8ms/step - loss: 0.0738 - accuracy: 0.9831
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0925 - accuracy: 0.9800
#
# PREDICTION ACCURACY (%):
# Train: 98.312, Test: 98.000

# %%
plotWeight([1,2,3,4], attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah)
# Out:
# Input: [1, 2, 3, 4]
# Predicted translation: [4, 3, 2, 1]

# %%
plotWeight([1,2,3,4], attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah)
# Out:
# Input: [1, 2, 3, 4]
# Predicted: [4, 3, 2, 1]

# %%
plotWeight([9,2,3,9], attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah)
# Out:
# Input: [9, 2, 3, 9]
# Predicted: [9, 3, 2, 9]

# %% [markdown]
# # Luong General Attention

# %%
# attention model
attentionLuongGeneral = LuongGeneralAttention(units = batch_size)
model_attentionLuongGeneral, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen = build_attention_model(attentionLuongGeneral, batch_size, rnn_units)


#training
train_test(model_attentionLuongGeneral, X_train, y_train , X_test,
           y_test, batch_size=batch_size, epochs=7, patience=3)
# Out:
# Epoch 1/7
# 1800/1800 [==============================] - 38s 17ms/step - loss: 1.5940 - accuracy: 0.3710 - val_loss: 1.2941 - val_accuracy: 0.4562
# Epoch 2/7
# 1800/1800 [==============================] - 29s 16ms/step - loss: 1.2013 - accuracy: 0.4896 - val_loss: 1.0657 - val_accuracy: 0.5487
# Epoch 3/7
# 1800/1800 [==============================] - 40s 22ms/step - loss: 0.9702 - accuracy: 0.5994 - val_loss: 0.8510 - val_accuracy: 0.6325
# Epoch 4/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.7202 - accuracy: 0.7208 - val_loss: 0.5831 - val_accuracy: 0.7850
# Epoch 5/7
# 1800/1800 [==============================] - 28s 16ms/step - loss: 0.4108 - accuracy: 0.8743 - val_loss: 0.3025 - val_accuracy: 0.9125
# Epoch 6/7
# 1800/1800 [==============================] - 28s 16ms/step - loss: 0.2154 - accuracy: 0.9517 - val_loss: 0.1744 - val_accuracy: 0.9700
# Epoch 7/7
# 1800/1800 [==============================] - 28s 15ms/step - loss: 0.1291 - accuracy: 0.9821 - val_loss: 0.0905 - val_accuracy: 0.9838
# 2000/2000 [==============================] - 15s 8ms/step - loss: 0.0782 - accuracy: 0.9948
# 200/200 [==============================] - 2s 8ms/step - loss: 0.1021 - accuracy: 0.9825
#
# PREDICTION ACCURACY (%):
# Train: 99.475, Test: 98.250

# %%
plotWeight([9,2,3,9], attentionLuongGeneral, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen)
# Out:
# Input: [9, 2, 3, 9]
# Predicted: [9, 3, 2, 9]

# %% [markdown]
# <a href="https://colab.research.google.com/github/JanLeyva/DeepLearning/blob/main/Copia_de_Assignment3Test7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# # Assignment 3: Attention
#
# The objectives of this assignment are:
#
# + To implement Bahdanau Attention and Luong General Attention classes.
# + To do a comparative (# of steps to converge, test error) of the three methods we have seen. Use these values for the comparative (the training datset size and `rnn_units` and `batch_size` values are up to you):
#     + `n_timesteps_in = 100`
#     + `n_features = 20`.
# + To implement a function to visualize the attention weights for one example. You can visualize them as in this figure (that corresponds to a machine translation task):
#
# <div>
# <center>
# <img src="https://jalammar.github.io/images/attention_sentence.png" width="200">
# </center>
# </div>
#
# + To write a blog entry explaining in your words how does attention work. You can do it in your favourite blog site. If you do not have a favourite blog site, you can start one here: https://hackmd.io/
#
# You have to report all your work at the end of this notebook.

# %% [markdown]
# # Code

# %%
#@title Some utils
from random import randint
import random
from matplotlib import pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

random.seed(12345678)


def generate_sequence(length, n_unique):
    """
    Generate a sequence of random integers.
    
    :length: Total length of the generated sequence
    :n_unique: Maximum number allowed
    """
    return [randint(1, n_unique-1) for _ in range(length)]

def one_hot_encode(sequence, n_unique):
    """
    Transform a sequence of integers into a one-hot-encoding vector
    
    :sequence: The sequence we want to transform
    :n_unique: Maximum number allowed (length of the one-hot-encoded vector)
    """
    encoding = list()
    for value in sequence:
        vector = [0 for _ in range(n_unique)]
        vector[value] = 1
        encoding.append(vector)
    return np.array(encoding)

def one_hot_decode(encoded_seq):
    """
    Transorm a one-hot-encoded vector into a list of integers
    
    :encoded_seq: One hot encoded sequence to be transformed
    """
    return [np.argmax(vector) for vector in encoded_seq]


def get_reversed_pairs(time_steps,vocabulary_size):
    """
    Generate a pair X, y where y is the 'reversed' version of X.
    
    :time_steps: Sequence length
    :vocabulary_size: Maximum number allowed
    """
    # generate random sequence and reverse it
    sequence_in = generate_sequence(time_steps, vocabulary_size)
    sequence_out = sequence_in[::-1]

    # one hot encode both sequences
    X = one_hot_encode(sequence_in, vocabulary_size)
    y = one_hot_encode(sequence_out, vocabulary_size)
    
    # reshape as 3D so it can be inputed to the LSTM
    X = X.reshape((1, X.shape[0], X.shape[1]))
    y = y.reshape((1, y.shape[0], y.shape[1]))
    return X,y


def create_dataset(train_size, test_size, time_steps,vocabulary_size):
    """
    Generates a datset of reversed pairs X, y.
    
    :train_size: Number of train pairs
    :test_size: Number of test pairs
    :time_steps: Sequence length
    :vocabulary_size: Maximum number allowed
    """
    
    # Generate reversed pairs for training
    pairs = [get_reversed_pairs(time_steps,vocabulary_size) for _ in range(train_size)]
    pairs= np.array(pairs).squeeze()
    X_train = pairs[:,0]
    y_train = pairs[:,1]
    
    # Generate reversed pairs for test
    pairs = [get_reversed_pairs(time_steps,vocabulary_size) for _ in range(test_size)]
    pairs= np.array(pairs).squeeze()
    X_test = pairs[:,0]
    y_test = pairs[:,1]	

    return X_train, y_train, X_test, y_test


def train_test(model, X_train, y_train , X_test, y_test, epochs=500, batch_size=32, patience=5):
    """
    It trains a model and evaluates the result on the test dataset
    
    :model: Model to be fit
    :X_train, y_train: Train samples and labels 
    :X_test y_test: Test samples and labels 
    :epochs: Maximum number of iterations that the model will perform
    :batch_size: Samples per batch
    :patience: Number of rounds without improvement that the model can perform. If there is no improvement on the loss, it will stop the trainning process.
    """
    
    # Train the model
    history=model.fit(X_train, y_train, 
                      validation_split= 0.1, 
                      epochs=epochs,
                      batch_size=batch_size, 
                      callbacks=[EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)])
    
    _, train_acc = model.evaluate(X_train, y_train, batch_size=batch_size)
    _, test_acc = model.evaluate(X_test, y_test, batch_size=batch_size)
    
    print('\nPREDICTION ACCURACY (%):')
    print('Train: %.3f, Test: %.3f' % (train_acc*100, test_acc*100))
    
    fig, axs = plt.subplots(1,2, figsize=(12,5))
    # summarize history for loss
    axs[0].plot(history.history['loss'])
    axs[0].plot(history.history['val_loss'])
    axs[0].set_title(model.name+' loss')
    axs[0].set_ylabel('loss')
    axs[0].set_xlabel('epoch')
    axs[0].legend(['train', 'val'], loc='upper left')
    
    # summarize history for accuracy
    axs[1].plot(history.history['accuracy'])
    axs[1].plot(history.history['val_accuracy'])
    axs[1].set_title(model.name+' accuracy')
    axs[1].set_ylabel('accuracy')
    axs[1].set_xlabel('epoch')
    axs[1].legend(['train', 'val'], loc='upper left')
    plt.show()
    
    
def predict(model, n_timesteps_in,n_features, x, y_real=None, batch_size = 1):
    pred=model.predict(x.reshape(1,n_timesteps_in,n_features), batch_size= batch_size)
    print('input', one_hot_decode(x))    
    print('predicted', one_hot_decode(pred[0]))
    if y_real is not None:
        print('expected', one_hot_decode(y_real))

# %%
# @title build_attention_model function <- to delet

import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

tf.keras.backend.set_floatx('float64')

#attention model
def build_attention_model(attention, batch_size, rnn_units):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')
    decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense')
    
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = np.zeros((batch_size, 1, n_features))
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for _ in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states)
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        context_vector = tf.expand_dims(context_vector, 1)

        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model, encoder_lstm, decoder_lstm, decoder_dense

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

tf.keras.backend.set_floatx('float64')

#attention model
def build_attention_model(attention, batch_size, rnn_units):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')
    decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense')
    
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = np.zeros((batch_size, 1, n_features))
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for _ in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states)
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        context_vector = tf.expand_dims(context_vector, 1)

        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ## LuongDotAttention
#
# Luong Dot Attention score is defined by:
#
# $$score(h_t,\hat{h}_s)= h_t^T \hat{h}_s$$
#
#
# This function was presentated in the paper [Effective Approaches to Attention-based Neural Machine Translation, 2015](https://arxiv.org/abs/1508.04025). In this paper they present the Dot Luong Attention and the General Luong. Notice that this attention function don't have training paramaters.

# %%
class LuongDotAttention(tf.keras.layers.Layer):
    def __init__(self):
        super(LuongDotAttention, self).__init__()

    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        values_transposed = tf.transpose(values, perm=[0, 2, 1])

        # LUONGH Dot-product
        score = tf.transpose(tf.matmul(query_with_time_axis, 
                                       values_transposed), perm=[0, 2, 1])

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %% [markdown]
# ### Defining parameters

# %%
# Assignment parameters
# dataset 
n_timesteps_in = 100  # Sequence length
n_features = 20     # Maximum number allowed-1 (length of the one-hot-encoded vector)
train_sizeA = 2000 
test_sizeA = 200
X_trainA, y_trainA, X_testA, y_testA = create_dataset(train_sizeA, test_sizeA, n_timesteps_in, n_features )

# training parameters
batch_sizeA = 100

# model parameters
rnn_unitsA = 100

# %%
# dataset 
n_timesteps_in = 100  # Sequence length
n_features = 20     # Maximum number allowed-1 (length of the one-hot-encoded vector)
train_size = 2000 
test_size = 200
X_train, y_train, X_test, y_test = create_dataset(train_size, test_size, n_timesteps_in,n_features )

# training parameters
batch_size = 100

# model parameters
rnn_units = 100

# %% [markdown]
# ## Attention model - Luong Dot

# %%
# attention model
attentionA = LuongDotAttention()
model_attentionA, encoder_lstm, decoder_lstm, decoder_dense  = build_attention_model(attentionA, batch_sizeA, rnn_unitsA) 
# we need this encoder/decoder for the weight representation

# %%
# attention model
attention = LuongDotAttention()
model_attention = build_attention_model(attention, batch_size, rnn_units) 
# we need this encoder/decoder for the weight representation

# %% [markdown]
# ### Training model

# %%
# Assignment paramenters
train_test(model_attention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 213s 3s/step - loss: 2.9633 - accuracy: 0.0556 - val_loss: 2.9467 - val_accuracy: 0.0539
# Epoch 2/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.9447 - accuracy: 0.0553 - val_loss: 2.9434 - val_accuracy: 0.0553
# Epoch 3/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.9417 - accuracy: 0.0614 - val_loss: 2.9399 - val_accuracy: 0.0677
# Epoch 4/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.9354 - accuracy: 0.0695 - val_loss: 2.9320 - val_accuracy: 0.0698
# Epoch 5/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.9253 - accuracy: 0.0769 - val_loss: 2.9188 - val_accuracy: 0.0800
# Epoch 6/50
# 18/18 [==============================] - 12s 678ms/step - loss: 2.9135 - accuracy: 0.0828 - val_loss: 2.9157 - val_accuracy: 0.0796
# Epoch 7/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.9059 - accuracy: 0.0868 - val_loss: 2.9031 - val_accuracy: 0.0890
# Epoch 8/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.8990 - accuracy: 0.0901 - val_loss: 2.8938 - val_accuracy: 0.0948
# Epoch 9/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.8852 - accuracy: 0.0958 - val_loss: 2.8768 - val_accuracy: 0.0993
# Epoch 10/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.8611 - accuracy: 0.1054 - val_loss: 2.8483 - val_accuracy: 0.1079
# Epoch 11/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.8278 - accuracy: 0.1169 - val_loss: 2.8024 - val_accuracy: 0.1260
# Epoch 12/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.7849 - accuracy: 0.1316 - val_loss: 2.7631 - val_accuracy: 0.1365
# Epoch 13/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.7441 - accuracy: 0.1433 - val_loss: 2.7438 - val_accuracy: 0.1437
# Epoch 14/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.7069 - accuracy: 0.1535 - val_loss: 2.6610 - val_accuracy: 0.1650
# Epoch 15/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.6346 - accuracy: 0.1723 - val_loss: 2.6229 - val_accuracy: 0.1727
# Epoch 16/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.5754 - accuracy: 0.1859 - val_loss: 2.5571 - val_accuracy: 0.1919
# Epoch 17/50
# 18/18 [==============================] - 12s 675ms/step - loss: 2.5189 - accuracy: 0.2006 - val_loss: 2.6390 - val_accuracy: 0.1666
# Epoch 18/50
# 18/18 [==============================] - 12s 675ms/step - loss: 2.5272 - accuracy: 0.1981 - val_loss: 2.4505 - val_accuracy: 0.2203
# Epoch 19/50
# 18/18 [==============================] - 12s 691ms/step - loss: 2.4165 - accuracy: 0.2235 - val_loss: 2.4049 - val_accuracy: 0.2275
# Epoch 20/50
# 18/18 [==============================] - 12s 664ms/step - loss: 2.4124 - accuracy: 0.2239 - val_loss: 2.3297 - val_accuracy: 0.2459
# Epoch 21/50
# 18/18 [==============================] - 12s 677ms/step - loss: 2.3316 - accuracy: 0.2419 - val_loss: 2.2883 - val_accuracy: 0.2537
# Epoch 22/50
# 18/18 [==============================] - 11s 632ms/step - loss: 2.2867 - accuracy: 0.2500 - val_loss: 2.2217 - val_accuracy: 0.2681
# Epoch 23/50
# 18/18 [==============================] - 11s 607ms/step - loss: 2.2367 - accuracy: 0.2597 - val_loss: 2.1746 - val_accuracy: 0.2741
# Epoch 24/50
# 18/18 [==============================] - 11s 607ms/step - loss: 2.1463 - accuracy: 0.2807 - val_loss: 2.1685 - val_accuracy: 0.2687
# Epoch 25/50
# 18/18 [==============================] - 12s 668ms/step - loss: 2.0937 - accuracy: 0.2900 - val_loss: 2.0723 - val_accuracy: 0.2975
# Epoch 26/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.1903 - accuracy: 0.2656 - val_loss: 2.0476 - val_accuracy: 0.3016
# Epoch 27/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.9921 - accuracy: 0.3132 - val_loss: 1.9560 - val_accuracy: 0.3209
# Epoch 28/50
# 18/18 [==============================] - 12s 690ms/step - loss: 1.9728 - accuracy: 0.3141 - val_loss: 1.8911 - val_accuracy: 0.3400
# Epoch 29/50
# 18/18 [==============================] - 12s 675ms/step - loss: 1.9116 - accuracy: 0.3276 - val_loss: 1.8383 - val_accuracy: 0.3474
# Epoch 30/50
# 18/18 [==============================] - 12s 675ms/step - loss: 1.8889 - accuracy: 0.3294 - val_loss: 1.8672 - val_accuracy: 0.3297
# Epoch 31/50
# 18/18 [==============================] - 12s 678ms/step - loss: 1.8392 - accuracy: 0.3402 - val_loss: 1.7982 - val_accuracy: 0.3544
# Epoch 32/50
# 18/18 [==============================] - 12s 690ms/step - loss: 1.7708 - accuracy: 0.3594 - val_loss: 1.7128 - val_accuracy: 0.3787
# Epoch 33/50
# 18/18 [==============================] - 12s 690ms/step - loss: 1.7104 - accuracy: 0.3750 - val_loss: 1.6869 - val_accuracy: 0.3839
# Epoch 34/50
# 18/18 [==============================] - 12s 689ms/step - loss: 1.7399 - accuracy: 0.3626 - val_loss: 1.7054 - val_accuracy: 0.3700
# Epoch 35/50
# 18/18 [==============================] - 12s 689ms/step - loss: 1.6492 - accuracy: 0.3888 - val_loss: 1.6076 - val_accuracy: 0.3996
# Epoch 36/50
# 18/18 [==============================] - 12s 676ms/step - loss: 1.6474 - accuracy: 0.3852 - val_loss: 1.6259 - val_accuracy: 0.3987
# Epoch 37/50
# 18/18 [==============================] - 12s 678ms/step - loss: 1.6087 - accuracy: 0.3993 - val_loss: 1.5663 - val_accuracy: 0.4085
# Epoch 38/50
# 18/18 [==============================] - 12s 677ms/step - loss: 1.6960 - accuracy: 0.3658 - val_loss: 1.5663 - val_accuracy: 0.4117
# Epoch 39/50
# 18/18 [==============================] - 12s 691ms/step - loss: 1.7468 - accuracy: 0.3639 - val_loss: 2.2734 - val_accuracy: 0.2086
# Epoch 40/50
# 18/18 [==============================] - 12s 689ms/step - loss: 1.6992 - accuracy: 0.3695 - val_loss: 1.4811 - val_accuracy: 0.4427
# Epoch 41/50
# 18/18 [==============================] - 12s 690ms/step - loss: 1.4551 - accuracy: 0.4476 - val_loss: 1.3719 - val_accuracy: 0.4790
# Epoch 42/50
# 18/18 [==============================] - 12s 678ms/step - loss: 1.3969 - accuracy: 0.4663 - val_loss: 1.3114 - val_accuracy: 0.5054
# Epoch 43/50
# 18/18 [==============================] - 12s 677ms/step - loss: 1.3376 - accuracy: 0.4891 - val_loss: 1.4330 - val_accuracy: 0.4394
# Epoch 44/50
# 18/18 [==============================] - 12s 691ms/step - loss: 1.3482 - accuracy: 0.4784 - val_loss: 1.2306 - val_accuracy: 0.5370
# Epoch 45/50
# 18/18 [==============================] - 12s 675ms/step - loss: 1.3271 - accuracy: 0.4867 - val_loss: 1.3086 - val_accuracy: 0.5007
# Epoch 46/50
# 18/18 [==============================] - 12s 676ms/step - loss: 1.3878 - accuracy: 0.4616 - val_loss: 1.3557 - val_accuracy: 0.4750
# Epoch 47/50
# 18/18 [==============================] - 12s 676ms/step - loss: 1.2511 - accuracy: 0.5164 - val_loss: 1.2685 - val_accuracy: 0.5113
# 20/20 [==============================] - 4s 201ms/step - loss: 1.2151 - accuracy: 0.5433
# 2/2 [==============================] - 0s 208ms/step - loss: 1.2400 - accuracy: 0.5342
#
# PREDICTION ACCURACY (%):
# Train: 54.334, Test: 53.420

# %%
# Assignment paramenters
train_test(model_attention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 217s 3s/step - loss: 2.9662 - accuracy: 0.0533 - val_loss: 2.9485 - val_accuracy: 0.0594
# Epoch 2/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.9449 - accuracy: 0.0573 - val_loss: 2.9429 - val_accuracy: 0.0524
# Epoch 3/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.9403 - accuracy: 0.0635 - val_loss: 2.9384 - val_accuracy: 0.0638
# Epoch 4/50
# 18/18 [==============================] - 12s 685ms/step - loss: 2.9328 - accuracy: 0.0698 - val_loss: 2.9306 - val_accuracy: 0.0701
# Epoch 5/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.9244 - accuracy: 0.0763 - val_loss: 2.9218 - val_accuracy: 0.0776
# Epoch 6/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.9168 - accuracy: 0.0807 - val_loss: 2.9161 - val_accuracy: 0.0798
# Epoch 7/50
# 18/18 [==============================] - 12s 671ms/step - loss: 2.9084 - accuracy: 0.0852 - val_loss: 2.9051 - val_accuracy: 0.0848
# Epoch 8/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.8999 - accuracy: 0.0891 - val_loss: 2.8958 - val_accuracy: 0.0898
# Epoch 9/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.8894 - accuracy: 0.0932 - val_loss: 2.8820 - val_accuracy: 0.0973
# Epoch 10/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.8745 - accuracy: 0.0992 - val_loss: 2.8711 - val_accuracy: 0.1010
# Epoch 11/50
# 18/18 [==============================] - 12s 670ms/step - loss: 2.8533 - accuracy: 0.1077 - val_loss: 2.8364 - val_accuracy: 0.1121
# Epoch 12/50
# 18/18 [==============================] - 12s 670ms/step - loss: 2.8033 - accuracy: 0.1256 - val_loss: 2.7868 - val_accuracy: 0.1305
# Epoch 13/50
# 18/18 [==============================] - 12s 671ms/step - loss: 2.7495 - accuracy: 0.1429 - val_loss: 2.7170 - val_accuracy: 0.1520
# Epoch 14/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.6886 - accuracy: 0.1590 - val_loss: 2.6521 - val_accuracy: 0.1709
# Epoch 15/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.6295 - accuracy: 0.1747 - val_loss: 2.6362 - val_accuracy: 0.1682
# Epoch 16/50
# 18/18 [==============================] - 12s 670ms/step - loss: 2.5614 - accuracy: 0.1899 - val_loss: 2.5153 - val_accuracy: 0.2018
# Epoch 17/50
# 18/18 [==============================] - 12s 670ms/step - loss: 2.5115 - accuracy: 0.2006 - val_loss: 2.6699 - val_accuracy: 0.1631
# Epoch 18/50
# 18/18 [==============================] - 12s 670ms/step - loss: 2.5398 - accuracy: 0.1948 - val_loss: 2.4622 - val_accuracy: 0.2112
# Epoch 19/50
# 18/18 [==============================] - 12s 671ms/step - loss: 2.4263 - accuracy: 0.2195 - val_loss: 2.4561 - val_accuracy: 0.2103
# Epoch 20/50
# 18/18 [==============================] - 12s 643ms/step - loss: 2.3814 - accuracy: 0.2288 - val_loss: 2.3882 - val_accuracy: 0.2270
# Epoch 21/50
# 18/18 [==============================] - 12s 685ms/step - loss: 2.3602 - accuracy: 0.2311 - val_loss: 2.2924 - val_accuracy: 0.2507
# Epoch 22/50
# 18/18 [==============================] - 12s 684ms/step - loss: 2.2578 - accuracy: 0.2546 - val_loss: 2.2717 - val_accuracy: 0.2494
# Epoch 23/50
# 18/18 [==============================] - 12s 683ms/step - loss: 2.2193 - accuracy: 0.2609 - val_loss: 2.2295 - val_accuracy: 0.2545
# Epoch 24/50
# 18/18 [==============================] - 12s 667ms/step - loss: 2.2465 - accuracy: 0.2539 - val_loss: 2.1317 - val_accuracy: 0.2831
# Epoch 25/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.1816 - accuracy: 0.2673 - val_loss: 2.0873 - val_accuracy: 0.2884
# Epoch 26/50
# 18/18 [==============================] - 12s 660ms/step - loss: 2.0592 - accuracy: 0.2948 - val_loss: 1.9986 - val_accuracy: 0.3089
# Epoch 27/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.0236 - accuracy: 0.2994 - val_loss: 1.9728 - val_accuracy: 0.3130
# Epoch 28/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.0274 - accuracy: 0.2961 - val_loss: 1.9492 - val_accuracy: 0.3187
# Epoch 29/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.9178 - accuracy: 0.3222 - val_loss: 2.1017 - val_accuracy: 0.2718
# Epoch 30/50
# 18/18 [==============================] - 12s 671ms/step - loss: 1.9985 - accuracy: 0.2979 - val_loss: 2.0023 - val_accuracy: 0.3036
# Epoch 31/50
# 18/18 [==============================] - 12s 671ms/step - loss: 1.8609 - accuracy: 0.3339 - val_loss: 1.7842 - val_accuracy: 0.3515
# Epoch 32/50
# 18/18 [==============================] - 12s 685ms/step - loss: 1.7967 - accuracy: 0.3467 - val_loss: 1.7357 - val_accuracy: 0.3620
# Epoch 33/50
# 18/18 [==============================] - 12s 685ms/step - loss: 1.7658 - accuracy: 0.3524 - val_loss: 1.8430 - val_accuracy: 0.3169
# Epoch 34/50
# 18/18 [==============================] - 12s 685ms/step - loss: 1.7173 - accuracy: 0.3633 - val_loss: 1.6630 - val_accuracy: 0.3791
# Epoch 35/50
# 18/18 [==============================] - 12s 686ms/step - loss: 1.6478 - accuracy: 0.3823 - val_loss: 1.7281 - val_accuracy: 0.3613
# Epoch 36/50
# 18/18 [==============================] - 12s 671ms/step - loss: 1.6156 - accuracy: 0.3902 - val_loss: 1.6129 - val_accuracy: 0.3868
# Epoch 37/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.5575 - accuracy: 0.4074 - val_loss: 1.5710 - val_accuracy: 0.3983
# Epoch 38/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.5516 - accuracy: 0.4081 - val_loss: 1.5335 - val_accuracy: 0.4033
# Epoch 39/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.5033 - accuracy: 0.4226 - val_loss: 1.4817 - val_accuracy: 0.4290
# Epoch 40/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.5249 - accuracy: 0.4122 - val_loss: 1.5099 - val_accuracy: 0.4225
# Epoch 41/50
# 18/18 [==============================] - 12s 641ms/step - loss: 1.5696 - accuracy: 0.4006 - val_loss: 1.4826 - val_accuracy: 0.4259
# Epoch 42/50
# 18/18 [==============================] - 12s 671ms/step - loss: 1.4241 - accuracy: 0.4464 - val_loss: 1.3749 - val_accuracy: 0.4608
# Epoch 43/50
# 18/18 [==============================] - 12s 687ms/step - loss: 1.3576 - accuracy: 0.4723 - val_loss: 1.2572 - val_accuracy: 0.5184
# Epoch 44/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.2983 - accuracy: 0.4954 - val_loss: 1.2181 - val_accuracy: 0.5345
# Epoch 45/50
# 18/18 [==============================] - 12s 671ms/step - loss: 1.2883 - accuracy: 0.4984 - val_loss: 1.4503 - val_accuracy: 0.4249
# Epoch 46/50
# 18/18 [==============================] - 12s 685ms/step - loss: 1.2702 - accuracy: 0.5025 - val_loss: 1.1525 - val_accuracy: 0.5556
# Epoch 47/50
# 18/18 [==============================] - 12s 671ms/step - loss: 1.1475 - accuracy: 0.5605 - val_loss: 1.4862 - val_accuracy: 0.4333
# Epoch 48/50
# 18/18 [==============================] - 12s 685ms/step - loss: 1.2525 - accuracy: 0.5122 - val_loss: 1.3742 - val_accuracy: 0.4294
# Epoch 49/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.3359 - accuracy: 0.4788 - val_loss: 1.4317 - val_accuracy: 0.3972
# 20/20 [==============================] - 4s 202ms/step - loss: 1.1286 - accuracy: 0.5724
# 2/2 [==============================] - 0s 210ms/step - loss: 1.1394 - accuracy: 0.5678
#
# PREDICTION ACCURACY (%):
# Train: 57.244, Test: 56.780

# %% [markdown]
# # Bahdanau Attention
#
# Bahdanau attention function is defined by:
#
# $$ score(h_t, \hat{h}_s)=V^Ttanh(W_a[h_t:\hat{h}_s])$$
#
# This function was presented on the paper [Neural Machine Translation by Jointly Learning to Align and Translate, 2014](https://arxiv.org/abs/1409.0473). This paper introduced and refined a technique called
# “Attention”. The function include 2 trainable weight matrix ($W_{a1}, W_{a2}$), $V$ is a weight vector and $tanh$ to scale numbers [-1,1].

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):

    query_with_time_axis = tf.expand_dims(query, 1)

    score = self.V(tf.nn.tanh(self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values

    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %% [markdown]
# # with assignment parameters

# %%
# attention model
attentionBahdanauAttentionA = BahdanauAttention(100)
model_attentionBahdanauAttentionA, encoder_lstmBah, decoder_lstmBah, decoder_denseBah = build_attention_model(attentionBahdanauAttentionA, batch_sizeA, rnn_unitsA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-03be952a6691> in <module>()
#       1 # attention model
#       2 attentionBahdanauAttentionA = BahdanauAttention(100)
# ----> 3 model_attentionBahdanauAttentionA, encoder_lstmBah, decoder_lstmBah, decoder_denseBah = build_attention_model(attentionBahdanauAttentionA, batch_sizeA, rnn_unitsA)
#
# NameError: name 'batch_sizeA' is not defined

# %%
# attention model
attentionBahdanauAttention = BahdanauAttention(100)
model_attentionBahdanauAttention = build_attention_model(attentionBahdanauAttention, batch_size, rnn_units)

# %%
train_test(model_attentionBahdanauAttention, X_train, y_train , X_test,
           y_test, batch_size=batch_size, epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 297s 4s/step - loss: 2.9642 - accuracy: 0.0522 - val_loss: 2.9466 - val_accuracy: 0.0537
# Epoch 2/50
# 18/18 [==============================] - 14s 786ms/step - loss: 2.9450 - accuracy: 0.0578 - val_loss: 2.9442 - val_accuracy: 0.0532
# Epoch 3/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.9400 - accuracy: 0.0627 - val_loss: 2.9388 - val_accuracy: 0.0664
# Epoch 4/50
# 18/18 [==============================] - 14s 777ms/step - loss: 2.9327 - accuracy: 0.0710 - val_loss: 2.9306 - val_accuracy: 0.0717
# Epoch 5/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.9253 - accuracy: 0.0747 - val_loss: 2.9233 - val_accuracy: 0.0789
# Epoch 6/50
# 18/18 [==============================] - 14s 776ms/step - loss: 2.9195 - accuracy: 0.0794 - val_loss: 2.9167 - val_accuracy: 0.0791
# Epoch 7/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.9125 - accuracy: 0.0832 - val_loss: 2.9084 - val_accuracy: 0.0819
# Epoch 8/50
# 18/18 [==============================] - 14s 775ms/step - loss: 2.9071 - accuracy: 0.0849 - val_loss: 2.9038 - val_accuracy: 0.0853
# Epoch 9/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.9005 - accuracy: 0.0886 - val_loss: 2.8974 - val_accuracy: 0.0888
# Epoch 10/50
# 18/18 [==============================] - 14s 774ms/step - loss: 2.8924 - accuracy: 0.0923 - val_loss: 2.8883 - val_accuracy: 0.0944
# Epoch 11/50
# 18/18 [==============================] - 14s 764ms/step - loss: 2.8811 - accuracy: 0.0964 - val_loss: 2.8773 - val_accuracy: 0.0972
# Epoch 12/50
# 18/18 [==============================] - 14s 774ms/step - loss: 2.8656 - accuracy: 0.1025 - val_loss: 2.8552 - val_accuracy: 0.1050
# Epoch 13/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.8359 - accuracy: 0.1126 - val_loss: 2.8181 - val_accuracy: 0.1177
# Epoch 14/50
# 18/18 [==============================] - 14s 767ms/step - loss: 2.7884 - accuracy: 0.1294 - val_loss: 2.7449 - val_accuracy: 0.1479
# Epoch 15/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.7334 - accuracy: 0.1468 - val_loss: 2.6941 - val_accuracy: 0.1588
# Epoch 16/50
# 18/18 [==============================] - 14s 776ms/step - loss: 2.6667 - accuracy: 0.1646 - val_loss: 2.6209 - val_accuracy: 0.1779
# Epoch 17/50
# 18/18 [==============================] - 14s 776ms/step - loss: 2.5900 - accuracy: 0.1825 - val_loss: 2.5928 - val_accuracy: 0.1794
# Epoch 18/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.5377 - accuracy: 0.1941 - val_loss: 2.5185 - val_accuracy: 0.1991
# Epoch 19/50
# 18/18 [==============================] - 14s 775ms/step - loss: 2.6674 - accuracy: 0.1639 - val_loss: 2.6601 - val_accuracy: 0.1696
# Epoch 20/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.5849 - accuracy: 0.1862 - val_loss: 2.4973 - val_accuracy: 0.2030
# Epoch 21/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.4802 - accuracy: 0.2074 - val_loss: 2.4363 - val_accuracy: 0.2145
# Epoch 22/50
# 18/18 [==============================] - 14s 773ms/step - loss: 2.3988 - accuracy: 0.2254 - val_loss: 2.3696 - val_accuracy: 0.2316
# Epoch 23/50
# 18/18 [==============================] - 14s 774ms/step - loss: 2.3371 - accuracy: 0.2389 - val_loss: 2.3728 - val_accuracy: 0.2253
# Epoch 24/50
# 18/18 [==============================] - 14s 774ms/step - loss: 2.3145 - accuracy: 0.2400 - val_loss: 2.2452 - val_accuracy: 0.2596
# Epoch 25/50
# 18/18 [==============================] - 14s 775ms/step - loss: 2.2388 - accuracy: 0.2575 - val_loss: 2.2192 - val_accuracy: 0.2589
# Epoch 26/50
# 18/18 [==============================] - 14s 765ms/step - loss: 2.2060 - accuracy: 0.2640 - val_loss: 2.1812 - val_accuracy: 0.2701
# Epoch 27/50
# 18/18 [==============================] - 14s 775ms/step - loss: 2.1481 - accuracy: 0.2766 - val_loss: 2.1369 - val_accuracy: 0.2761
# Epoch 28/50
# 18/18 [==============================] - 14s 766ms/step - loss: 2.1567 - accuracy: 0.2693 - val_loss: 2.1743 - val_accuracy: 0.2631
# Epoch 29/50
# 18/18 [==============================] - 14s 764ms/step - loss: 2.3862 - accuracy: 0.2283 - val_loss: 3.1440 - val_accuracy: 0.0703
# Epoch 30/50
# 18/18 [==============================] - 14s 776ms/step - loss: 3.0238 - accuracy: 0.0796 - val_loss: 2.9041 - val_accuracy: 0.0890
# 20/20 [==============================] - 6s 277ms/step - loss: 2.1367 - accuracy: 0.2752
# 2/2 [==============================] - 1s 266ms/step - loss: 2.1416 - accuracy: 0.2756
#
# PREDICTION ACCURACY (%):
# Train: 27.523, Test: 27.560

# %%
train_test(model_attentionBahdanauAttentionA, X_trainA, y_trainA , X_testA,
           y_testA, batch_size=batch_sizeA,epochs=50, patience=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f86faa530d3c> in <module>()
# ----> 1 train_test(model_attentionBahdanauAttentionA, X_trainA, y_trainA , X_testA,
#       2            y_testA, batch_size=batch_sizeA,epochs=50, patience=3)
#
# NameError: name 'model_attentionBahdanauAttentionA' is not defined

# %% [markdown]
# # LuongGeneralAttention
#
# Luong General Attention function is defined by:
#
# $$score(h_t,\hat{h}_s)= h_t^T W_a\hat{h}_s$$
#
# This function was presentated in the paper [Effective Approaches to Attention-based Neural Machine Translation, 2015](https://arxiv.org/abs/1508.04025). In this paper they present the Dot Luong Attention and the General Luong. The Luong general got a $W_a$ to be trained in order to get better performance.

# %%
class LuongGeneralAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(LuongGeneralAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)


    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        values_transposed = tf.transpose(values, perm=[0, 2, 1])

        # LUONGH Dot-product
        score = tf.transpose(tf.matmul(query_with_time_axis, 
                                       self.W1(values)), perm=[0, 2, 1])

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class LuongGeneralAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(LuongGeneralAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)


    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        values_transposed = tf.transpose(values, perm=[0, 2, 1])

        # LUONGH general with W weight to train
        WValuesT = self.W1(values_transposed)
        score = tf.transpose(tf.matmul((query_with_time_axis), 
                                       (WValuesT)), perm=[0, 2, 1])

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
# attention model
attentionLuongGeneral = LuongGeneralAttention(units = 100)
model_attentionLuongGeneral = build_attention_model(attentionLuongGeneral, batch_size, rnn_units)


#training
train_test(model_attentionLuongGeneral, X_train, y_train , X_test,
           y_test, batch_size=batch_size, epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 219s 3s/step - loss: 2.9642 - accuracy: 0.0539 - val_loss: 2.9459 - val_accuracy: 0.0529
# Epoch 2/50
# 18/18 [==============================] - 13s 718ms/step - loss: 2.9446 - accuracy: 0.0557 - val_loss: 2.9429 - val_accuracy: 0.0609
# Epoch 3/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.9411 - accuracy: 0.0634 - val_loss: 2.9402 - val_accuracy: 0.0649
# Epoch 4/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.9368 - accuracy: 0.0685 - val_loss: 2.9310 - val_accuracy: 0.0712
# Epoch 5/50
# 18/18 [==============================] - 12s 676ms/step - loss: 2.9246 - accuracy: 0.0782 - val_loss: 2.9186 - val_accuracy: 0.0814
# Epoch 6/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.9055 - accuracy: 0.0895 - val_loss: 2.8954 - val_accuracy: 0.0909
# Epoch 7/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.8825 - accuracy: 0.0980 - val_loss: 2.8913 - val_accuracy: 0.0945
# Epoch 8/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.8601 - accuracy: 0.1051 - val_loss: 2.8401 - val_accuracy: 0.1125
# Epoch 9/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.8286 - accuracy: 0.1162 - val_loss: 2.8495 - val_accuracy: 0.1103
# Epoch 10/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.7996 - accuracy: 0.1255 - val_loss: 2.7650 - val_accuracy: 0.1398
# Epoch 11/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.7752 - accuracy: 0.1314 - val_loss: 2.7458 - val_accuracy: 0.1396
# Epoch 12/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.7287 - accuracy: 0.1430 - val_loss: 2.8072 - val_accuracy: 0.1210
# Epoch 13/50
# 18/18 [==============================] - 12s 690ms/step - loss: 2.7110 - accuracy: 0.1486 - val_loss: 2.6648 - val_accuracy: 0.1595
# Epoch 14/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.6334 - accuracy: 0.1677 - val_loss: 2.6160 - val_accuracy: 0.1722
# Epoch 15/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.6322 - accuracy: 0.1671 - val_loss: 2.6347 - val_accuracy: 0.1663
# Epoch 16/50
# 18/18 [==============================] - 12s 689ms/step - loss: 2.5744 - accuracy: 0.1818 - val_loss: 2.5290 - val_accuracy: 0.1918
# Epoch 17/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.5063 - accuracy: 0.1953 - val_loss: 2.5421 - val_accuracy: 0.1852
# Epoch 18/50
# 18/18 [==============================] - 12s 689ms/step - loss: 2.4964 - accuracy: 0.1972 - val_loss: 2.4496 - val_accuracy: 0.2079
# Epoch 19/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.4158 - accuracy: 0.2139 - val_loss: 2.3865 - val_accuracy: 0.2232
# Epoch 20/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.3785 - accuracy: 0.2223 - val_loss: 2.3440 - val_accuracy: 0.2319
# Epoch 21/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.4112 - accuracy: 0.2125 - val_loss: 2.5770 - val_accuracy: 0.1734
# Epoch 22/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.3861 - accuracy: 0.2202 - val_loss: 2.3198 - val_accuracy: 0.2328
# Epoch 23/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.2837 - accuracy: 0.2407 - val_loss: 2.2576 - val_accuracy: 0.2482
# Epoch 24/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.2346 - accuracy: 0.2508 - val_loss: 2.2106 - val_accuracy: 0.2555
# Epoch 25/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.2127 - accuracy: 0.2515 - val_loss: 2.1761 - val_accuracy: 0.2594
# Epoch 26/50
# 18/18 [==============================] - 12s 671ms/step - loss: 2.1670 - accuracy: 0.2601 - val_loss: 2.1971 - val_accuracy: 0.2527
# Epoch 27/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.1529 - accuracy: 0.2612 - val_loss: 2.1484 - val_accuracy: 0.2629
# Epoch 28/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.1185 - accuracy: 0.2681 - val_loss: 2.1656 - val_accuracy: 0.2555
# Epoch 29/50
# 18/18 [==============================] - 12s 675ms/step - loss: 2.0866 - accuracy: 0.2736 - val_loss: 2.1165 - val_accuracy: 0.2670
# Epoch 30/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.0615 - accuracy: 0.2774 - val_loss: 2.0343 - val_accuracy: 0.2860
# Epoch 31/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.0472 - accuracy: 0.2796 - val_loss: 2.0800 - val_accuracy: 0.2707
# Epoch 32/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.9938 - accuracy: 0.2920 - val_loss: 2.0041 - val_accuracy: 0.2862
# Epoch 33/50
# 18/18 [==============================] - 12s 689ms/step - loss: 1.9598 - accuracy: 0.2979 - val_loss: 2.0167 - val_accuracy: 0.2781
# Epoch 34/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.9593 - accuracy: 0.2952 - val_loss: 1.8969 - val_accuracy: 0.3123
# Epoch 35/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.8796 - accuracy: 0.3146 - val_loss: 1.9405 - val_accuracy: 0.2989
# Epoch 36/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.8619 - accuracy: 0.3166 - val_loss: 1.8670 - val_accuracy: 0.3160
# Epoch 37/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.8259 - accuracy: 0.3250 - val_loss: 1.8424 - val_accuracy: 0.3206
# Epoch 38/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.8364 - accuracy: 0.3182 - val_loss: 1.7817 - val_accuracy: 0.3358
# Epoch 39/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.7702 - accuracy: 0.3378 - val_loss: 1.7348 - val_accuracy: 0.3466
# Epoch 40/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.8056 - accuracy: 0.3245 - val_loss: 1.7524 - val_accuracy: 0.3397
# Epoch 41/50
# 18/18 [==============================] - 12s 688ms/step - loss: 1.7362 - accuracy: 0.3450 - val_loss: 1.7063 - val_accuracy: 0.3513
# Epoch 42/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.7050 - accuracy: 0.3520 - val_loss: 1.7002 - val_accuracy: 0.3497
# Epoch 43/50
# 18/18 [==============================] - 12s 687ms/step - loss: 1.7460 - accuracy: 0.3369 - val_loss: 1.7348 - val_accuracy: 0.3443
# Epoch 44/50
# 18/18 [==============================] - 12s 688ms/step - loss: 1.6814 - accuracy: 0.3551 - val_loss: 1.6889 - val_accuracy: 0.3493
# Epoch 45/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.6262 - accuracy: 0.3716 - val_loss: 1.6511 - val_accuracy: 0.3588
# Epoch 46/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.6069 - accuracy: 0.3775 - val_loss: 1.5886 - val_accuracy: 0.3782
# Epoch 47/50
# 18/18 [==============================] - 12s 688ms/step - loss: 1.6230 - accuracy: 0.3685 - val_loss: 1.6148 - val_accuracy: 0.3645
# Epoch 48/50
# 18/18 [==============================] - 12s 689ms/step - loss: 1.6212 - accuracy: 0.3680 - val_loss: 1.5972 - val_accuracy: 0.3813
# Epoch 49/50
# 18/18 [==============================] - 12s 689ms/step - loss: 1.5826 - accuracy: 0.3804 - val_loss: 1.8198 - val_accuracy: 0.2846
# 20/20 [==============================] - 4s 195ms/step - loss: 1.5630 - accuracy: 0.3895
# 2/2 [==============================] - 0s 199ms/step - loss: 1.5882 - accuracy: 0.3822
#
# PREDICTION ACCURACY (%):
# Train: 38.950, Test: 38.220

# %%
# attention model
attentionLuongGeneralA = LuongGeneralAttention(units = 100)
model_attentionLuongGeneralA, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen = build_attention_model(attentionLuongGeneralA, batch_sizeA, rnn_unitsA)


#training
train_test(model_attentionLuongGeneralA, X_trainA, y_trainA , X_testA,
           y_testA, batch_size=batch_sizeA, epochs=50, patience=3)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 216s 3s/step - loss: 2.9660 - accuracy: 0.0534 - val_loss: 2.9471 - val_accuracy: 0.0520
# Epoch 2/50
# 18/18 [==============================] - 13s 690ms/step - loss: 2.9439 - accuracy: 0.0585 - val_loss: 2.9439 - val_accuracy: 0.0568
# Epoch 3/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.9386 - accuracy: 0.0640 - val_loss: 2.9331 - val_accuracy: 0.0667
# Epoch 4/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.9329 - accuracy: 0.0724 - val_loss: 2.9249 - val_accuracy: 0.0840
# Epoch 5/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.9147 - accuracy: 0.0821 - val_loss: 2.9005 - val_accuracy: 0.0887
# Epoch 6/50
# 18/18 [==============================] - 12s 671ms/step - loss: 2.8901 - accuracy: 0.0943 - val_loss: 2.9023 - val_accuracy: 0.0881
# Epoch 7/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.8888 - accuracy: 0.0944 - val_loss: 2.8689 - val_accuracy: 0.1021
# Epoch 8/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.8500 - accuracy: 0.1074 - val_loss: 2.8278 - val_accuracy: 0.1157
# Epoch 9/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.8409 - accuracy: 0.1108 - val_loss: 2.8215 - val_accuracy: 0.1200
# Epoch 10/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.7999 - accuracy: 0.1234 - val_loss: 2.7797 - val_accuracy: 0.1276
# Epoch 11/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.7756 - accuracy: 0.1308 - val_loss: 2.7696 - val_accuracy: 0.1366
# Epoch 12/50
# 18/18 [==============================] - 12s 685ms/step - loss: 2.7291 - accuracy: 0.1447 - val_loss: 2.6962 - val_accuracy: 0.1520
# Epoch 13/50
# 18/18 [==============================] - 12s 671ms/step - loss: 2.7142 - accuracy: 0.1486 - val_loss: 2.6866 - val_accuracy: 0.1565
# Epoch 14/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.6585 - accuracy: 0.1620 - val_loss: 2.6457 - val_accuracy: 0.1638
# Epoch 15/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.5999 - accuracy: 0.1756 - val_loss: 2.5765 - val_accuracy: 0.1792
# Epoch 16/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.5862 - accuracy: 0.1757 - val_loss: 2.6511 - val_accuracy: 0.1599
# Epoch 17/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.5500 - accuracy: 0.1856 - val_loss: 2.5399 - val_accuracy: 0.1852
# Epoch 18/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.5031 - accuracy: 0.1947 - val_loss: 2.5067 - val_accuracy: 0.1913
# Epoch 19/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.4755 - accuracy: 0.1995 - val_loss: 2.4672 - val_accuracy: 0.2007
# Epoch 20/50
# 18/18 [==============================] - 12s 674ms/step - loss: 2.4341 - accuracy: 0.2074 - val_loss: 2.4235 - val_accuracy: 0.2104
# Epoch 21/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.3851 - accuracy: 0.2181 - val_loss: 2.3593 - val_accuracy: 0.2231
# Epoch 22/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.3590 - accuracy: 0.2213 - val_loss: 2.3549 - val_accuracy: 0.2219
# Epoch 23/50
# 18/18 [==============================] - 12s 688ms/step - loss: 2.3308 - accuracy: 0.2269 - val_loss: 2.2923 - val_accuracy: 0.2353
# Epoch 24/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.3101 - accuracy: 0.2298 - val_loss: 2.3596 - val_accuracy: 0.2225
# Epoch 25/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.2717 - accuracy: 0.2372 - val_loss: 2.2335 - val_accuracy: 0.2461
# Epoch 26/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.2649 - accuracy: 0.2366 - val_loss: 2.2144 - val_accuracy: 0.2502
# Epoch 27/50
# 18/18 [==============================] - 12s 687ms/step - loss: 2.2038 - accuracy: 0.2487 - val_loss: 2.2111 - val_accuracy: 0.2475
# Epoch 28/50
# 18/18 [==============================] - 12s 673ms/step - loss: 2.1975 - accuracy: 0.2482 - val_loss: 2.2391 - val_accuracy: 0.2378
# Epoch 29/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.1422 - accuracy: 0.2604 - val_loss: 2.1114 - val_accuracy: 0.2670
# Epoch 30/50
# 18/18 [==============================] - 12s 685ms/step - loss: 2.2800 - accuracy: 0.2328 - val_loss: 2.2849 - val_accuracy: 0.2399
# Epoch 31/50
# 18/18 [==============================] - 12s 671ms/step - loss: 2.2349 - accuracy: 0.2432 - val_loss: 2.1563 - val_accuracy: 0.2562
# Epoch 32/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.0955 - accuracy: 0.2685 - val_loss: 2.0711 - val_accuracy: 0.2738
# Epoch 33/50
# 18/18 [==============================] - 12s 686ms/step - loss: 2.0621 - accuracy: 0.2746 - val_loss: 2.2191 - val_accuracy: 0.2331
# Epoch 34/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.0556 - accuracy: 0.2751 - val_loss: 2.0425 - val_accuracy: 0.2752
# Epoch 35/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.0096 - accuracy: 0.2843 - val_loss: 2.0113 - val_accuracy: 0.2825
# Epoch 36/50
# 18/18 [==============================] - 12s 672ms/step - loss: 2.0102 - accuracy: 0.2819 - val_loss: 1.9719 - val_accuracy: 0.2912
# Epoch 37/50
# 18/18 [==============================] - 12s 686ms/step - loss: 1.9624 - accuracy: 0.2941 - val_loss: 2.1548 - val_accuracy: 0.2334
# Epoch 38/50
# 18/18 [==============================] - 12s 686ms/step - loss: 1.9876 - accuracy: 0.2843 - val_loss: 1.9271 - val_accuracy: 0.3009
# Epoch 39/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.9287 - accuracy: 0.2979 - val_loss: 1.8920 - val_accuracy: 0.3096
# Epoch 40/50
# 18/18 [==============================] - 12s 688ms/step - loss: 1.9031 - accuracy: 0.3044 - val_loss: 1.8803 - val_accuracy: 0.3121
# Epoch 41/50
# 18/18 [==============================] - 12s 671ms/step - loss: 1.9183 - accuracy: 0.2990 - val_loss: 1.9046 - val_accuracy: 0.2992
# Epoch 42/50
# 18/18 [==============================] - 12s 673ms/step - loss: 1.8821 - accuracy: 0.3072 - val_loss: 1.8854 - val_accuracy: 0.3063
# Epoch 43/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.8511 - accuracy: 0.3139 - val_loss: 1.8417 - val_accuracy: 0.3189
# Epoch 44/50
# 18/18 [==============================] - 12s 672ms/step - loss: 1.8214 - accuracy: 0.3228 - val_loss: 1.8962 - val_accuracy: 0.2880
# Epoch 45/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.8272 - accuracy: 0.3197 - val_loss: 1.7867 - val_accuracy: 0.3290
# Epoch 46/50
# 18/18 [==============================] - 12s 673ms/step - loss: 1.8046 - accuracy: 0.3238 - val_loss: 1.8349 - val_accuracy: 0.3249
# Epoch 47/50
# 18/18 [==============================] - 12s 687ms/step - loss: 1.7904 - accuracy: 0.3271 - val_loss: 1.7286 - val_accuracy: 0.3527
# Epoch 48/50
# 18/18 [==============================] - 12s 674ms/step - loss: 1.7784 - accuracy: 0.3299 - val_loss: 1.7887 - val_accuracy: 0.3147
# Epoch 49/50
# 18/18 [==============================] - 12s 675ms/step - loss: 1.7492 - accuracy: 0.3368 - val_loss: 1.7155 - val_accuracy: 0.3484
# Epoch 50/50
# 18/18 [==============================] - 12s 688ms/step - loss: 1.7526 - accuracy: 0.3367 - val_loss: 1.7066 - val_accuracy: 0.3510
# 20/20 [==============================] - 5s 254ms/step - loss: 1.6953 - accuracy: 0.3532
# 2/2 [==============================] - 1s 252ms/step - loss: 1.7142 - accuracy: 0.3517
#
# PREDICTION ACCURACY (%):
# Train: 35.324, Test: 35.170

# %%
# attention model
attentionLuongGeneral = LuongGeneralAttention(units = 100)
model_attentionLuongGeneral = build_attention_model(attentionLuongGeneral, batch_size, rnn_units)


#training
train_test(model_attentionLuongGeneral, X_train, y_train , X_test,
           y_test, batch_size=batch_size, epochs=50, patience=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad883f52b6ae> in <module>()
#       1 # attention model
# ----> 2 attentionLuongGeneral = LuongGeneralAttention(units = 100)
#       3 model_attentionLuongGeneral = build_attention_model(attentionLuongGeneral, batch_size, rnn_units)
#       4
#       5
#
# NameError: name 'LuongGeneralAttention' is not defined

# %% [markdown]
# Esto funciona teniendo:
# Dataset formado por
# - n_timesteps_in = 100
# - n_features = 20
# - batch_size = 100
# - rnn_units = 100
#
# **El tema esta en tenir la mateixa rnn_units i batch_size**

# %% [markdown]
# # Results
#
# | Attention function  	| Accuracy  	|  Loss 	|
# |---                  	|---        	|---	    |
# | Luong Dot           	| 0.45      	| 0.2     |
# | Bahdanau  	          | 0.319  	      | 0.1     |
# | Luong General         | 0.331        |  1.7    |

# %% [markdown]
# ## Visualization the Scores
#
# #### Function to Plot Scores
#
# The idea is take the `build_function` and modify in order to get the `attention_weightPlot` and the `input_seq` and `out_seq`. For do that we need to take into account the following from our model:
# * `attention`: the Attention function (LuongDot, LuongGeneral, Bahdanau).
# * `encoder_lstm`: encoder used
# * `decoder_lstm`: decoder used
# * `decoder_dense`: decoder used

# %%
 #@title function to Compute and Plot the weight
# function to Compute and Plot the weight

import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K



def build_attention_weight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    #encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    #encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    attention_plot = np.zeros((n_timesteps_in, n_timesteps_in))
    sequence = one_hot_encode(seq_in,n_features)

    encoder_inputs=np.array(sequence).reshape(1,n_timesteps_in,n_features)
    encoder_inputs = tf.convert_to_tensor(encoder_inputs,dtype=tf.float32)

    # Def encoder_lstm
    #encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm') <--------- Usamos los entrenados
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    #decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')        # <--------- Usamos los entrenados
    #decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense') # <--------- Usamos los entrenados
    decoder_input_data = np.zeros((1, 1, n_features))
    decoder_input_data[:, 0, 0] = 1 
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = decoder_input_data
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for i in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states) <---------
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[i] = attention_weights.numpy()
        #context_vector = tf.expand_dims(context_vector, 1) <---------

        decoder_outputs=tf.expand_dims(decoder_outputs, 1)

        context_vector = tf.expand_dims(context_vector, 1)


        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)      
        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    seq_out=one_hot_decode(decoder_outputs[0])  # <---------

    
    #model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')  <---------
    #model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) <---------
    
    return seq_in, seq_out, attention_plot

# %% [markdown]
# ### Plot attention score weight function

# %%
from matplotlib import ticker
import seaborn as sns

def plot_attention(attention, sequence, predicted_sequence, weight_n = True):
  """ 
  attention: the attention function used to calc the weight
  if weight_n = True the weight number will appears, else not.
  """
  fig = plt.figure(figsize=(8,8))
  ax = fig.add_subplot(1, 1, 1)
  ax = sns.heatmap(attention, annot=weight_n, \
                     fmt='.2g', cmap='gist_gray')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sequence, fontdict=fontdict, rotation=45)
  ax.set_yticklabels([''] + predicted_sequence, rotation = 45, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()


def plotWeight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense, weight_n = True):
  seq_in, seq_out, attention_plot = build_attention_weight(seq_in, attention, encoder_lstm, decoder_lstm, decoder_dense)

  print('Input: %s' % (seq_in))
  print('Predicted: {}'.format(seq_out))

  attention_plot = attention_plot[:len(seq_out), :len(seq_in)]
  plot_attention(attention_plot, seq_in, seq_out, weight_n)

# %%
# @title build_attention_model function <- with encoders output

import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

tf.keras.backend.set_floatx('float64')

#attention model
def build_attention_model(attention, batch_size, rnn_units):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')
    decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense')
    
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = np.zeros((batch_size, 1, n_features))
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for _ in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states)
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        context_vector = tf.expand_dims(context_vector, 1)

        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model, encoder_lstm, decoder_lstm, decoder_dense

# %% [markdown]
# ### Example dataset:
# In order to see propertly the score weight in a heatplot we will use a small dataset reducing the number of times step and number of features.
# - n_timesteps_in = 4
# - n_features = 10
# - train_size = 2000
# - test_size = 200

# %%
#@title changed part n_timesteps_in, n_features
# dataset 
n_timesteps_in = 4  # Sequence length                                                 ## changed from 100 to 4
n_features = 10     # Maximum number allowed-1 (length of the one-hot-encoded vector) ## changed from 20 to 10
train_size = 2000 
test_size = 200
X_train, y_train, X_test, y_test = create_dataset(train_size, test_size, n_timesteps_in,n_features)

# training parameters
batch_size = 1

# model parameters
rnn_units = 16       # changed from 100 to 16

# %% [markdown]
# # Luong Dot Attention

# %%
# attention model
attention = LuongDotAttention()
model_attention, encoder_lstm, decoder_lstm, decoder_dense  = build_attention_model(attention, batch_size, rnn_units) 
# we need this encoder/decoder for the weight representation

train_test(model_attention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=7, patience=3)
# Out:
# Epoch 1/7
# 1800/1800 [==============================] - 36s 16ms/step - loss: 1.6820 - accuracy: 0.3515 - val_loss: 1.4339 - val_accuracy: 0.4113
# Epoch 2/7
# 1800/1800 [==============================] - 26s 15ms/step - loss: 1.2968 - accuracy: 0.4700 - val_loss: 1.0922 - val_accuracy: 0.5900
# Epoch 3/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.8861 - accuracy: 0.6660 - val_loss: 0.5981 - val_accuracy: 0.8200
# Epoch 4/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.3573 - accuracy: 0.9225 - val_loss: 0.1693 - val_accuracy: 0.9825
# Epoch 5/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.1168 - accuracy: 0.9893 - val_loss: 0.0833 - val_accuracy: 0.9912
# Epoch 6/7
# 1800/1800 [==============================] - 28s 15ms/step - loss: 0.0626 - accuracy: 0.9942 - val_loss: 0.0728 - val_accuracy: 0.9888
# Epoch 7/7
# 1800/1800 [==============================] - 29s 16ms/step - loss: 0.0345 - accuracy: 0.9982 - val_loss: 0.0269 - val_accuracy: 1.0000
# 2000/2000 [==============================] - 16s 8ms/step - loss: 0.0235 - accuracy: 0.9999
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0406 - accuracy: 0.9950
#
# PREDICTION ACCURACY (%):
# Train: 99.987, Test: 99.500

# %%
plotWeight([1,2,3,4], attention, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [1, 2, 3, 4]
# Predicted: [4, 3, 2, 1]

# %%
plotWeight([9,2,3,9], attention, encoder_lstm, decoder_lstm, decoder_dense)
# Out:
# Input: [9, 2, 3, 9]
# Predicted: [9, 3, 2, 9]

# %% [markdown]
# # Banhdanau Attention

# %%
# attention model
attentionBahdanauAttention = BahdanauAttention(16)
model_attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah = build_attention_model(attentionBahdanauAttention, batch_size, rnn_units)

train_test(model_attentionBahdanauAttention, X_train, y_train , X_test,
           y_test, batch_size=batch_size,epochs=7, patience=3)
# Out:
# Epoch 1/7
# 1800/1800 [==============================] - 41s 18ms/step - loss: 1.6272 - accuracy: 0.3685 - val_loss: 1.3580 - val_accuracy: 0.4163
# Epoch 2/7
# 1800/1800 [==============================] - 29s 16ms/step - loss: 1.1956 - accuracy: 0.4850 - val_loss: 0.9498 - val_accuracy: 0.6238
# Epoch 3/7
# 1800/1800 [==============================] - 29s 16ms/step - loss: 0.3712 - accuracy: 0.9058 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 4/7
# 1800/1800 [==============================] - 28s 16ms/step - loss: 0.0335 - accuracy: 0.9990 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 5/7
# 1800/1800 [==============================] - 30s 16ms/step - loss: 0.0286 - accuracy: 0.9950 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 6/7
# 1800/1800 [==============================] - 30s 17ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 7/7
# 1800/1800 [==============================] - 30s 17ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# 2000/2000 [==============================] - 16s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0018 - accuracy: 1.0000
#
# PREDICTION ACCURACY (%):
# Train: 100.000, Test: 100.000

# %%
plotWeight([1,2,3,4], attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah)
# Out:
# Input: [1, 2, 3, 4]
# Predicted: [4, 3, 2, 1]

# %%
plotWeight([9,2,3,9], attentionBahdanauAttention, encoder_lstmBah, decoder_lstmBah, decoder_denseBah)
# Out:
# Input: [9, 2, 3, 9]
# Predicted: [9, 3, 2, 9]

# %% [markdown]
# # Luong General Attention

# %%
# attention model
attentionLuongGeneral = LuongGeneralAttention(units = 4)
model_attentionLuongGeneral, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen = build_attention_model(attentionLuongGeneral, batch_size, rnn_units)


#training
train_test(model_attentionLuongGeneral, X_train, y_train , X_test,
           y_test, batch_size=batch_size, epochs=7, patience=3)
# Out:
# Epoch 1/7
# 1800/1800 [==============================] - 38s 17ms/step - loss: 1.6548 - accuracy: 0.3614 - val_loss: 1.3427 - val_accuracy: 0.4138
# Epoch 2/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 1.1807 - accuracy: 0.4840 - val_loss: 1.0061 - val_accuracy: 0.5725
# Epoch 3/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.5701 - accuracy: 0.8289 - val_loss: 0.1568 - val_accuracy: 0.9888
# Epoch 4/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.0562 - accuracy: 0.9990 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 5/7
# 1800/1800 [==============================] - 26s 15ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9988
# Epoch 6/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.0062 - accuracy: 0.9996 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 7/7
# 1800/1800 [==============================] - 27s 15ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# 2000/2000 [==============================] - 15s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0011 - accuracy: 1.0000
#
# PREDICTION ACCURACY (%):
# Train: 100.000, Test: 100.000

# %%
plotWeight([1,2,3,4], attentionLuongGeneral, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen)
# Out:
# Input: [1, 2, 3, 4]
# Predicted: [4, 3, 2, 1]

# %%
plotWeight([9,2,3,9], attentionLuongGeneral, encoder_lstmLuGen, decoder_lstmLuGen, decoder_denseLuGen)
# Out:
# Input: [9, 2, 3, 9]
# Predicted: [9, 3, 2, 9]
